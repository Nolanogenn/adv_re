# %%
import glob
import json
import altair as alt
import re
import os
import tqdm
from collections import Counter
import sklearn.metrics
import scipy.spatial.distance
import numpy as np
import math
import pandas as pd

# %%
data = {
    os.path.basename(f) : json.load(open(f))
    for f in glob.glob('./aggregated_files/*.json')
}
unist_mapping = json.load(open('./unist_mapping.json'))

# %%
def compute_micro_f1_tacred(targets, preds, no_relation_idx = ['no_relation', 'no relation']):
    guessed_by_relation = Counter()
    gold_by_relation = Counter()
    correct_by_relation = Counter()
    for row in range(len(preds)):
        gold = targets[row]
        guess = preds[row]

        if gold in no_relation_idx and guess in no_relation_idx:
            pass
        elif gold in no_relation_idx and guess not in no_relation_idx:
            guessed_by_relation[guess] += 1
        elif gold not in no_relation_idx and guess in no_relation_idx:
            gold_by_relation[gold] += 1
        elif gold not in no_relation_idx and guess not in no_relation_idx:
            guessed_by_relation[guess] += 1
            gold_by_relation[gold] += 1
            if gold == guess:
                correct_by_relation[guess] += 1

    prec_micro = 1.0
    if sum(guessed_by_relation.values()) > 0:
        prec_micro = float(sum(correct_by_relation.values())) / float(sum(guessed_by_relation.values()))
    recall_micro = 0.0
    if sum(gold_by_relation.values()) > 0:
        recall_micro = float(sum(correct_by_relation.values())) / float(sum(gold_by_relation.values()))
    f1_micro = 0.0
    if prec_micro + recall_micro > 0.0:
        f1_micro = (2.0 * prec_micro * recall_micro) / (prec_micro + recall_micro)
    return f1_micro

# %%
test_f1s = {m:0 for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']}

for model in test_f1s:
    preds_test = json.load(open(f'./models/{model}/test.json'))
    pred = [x[0] for x in preds_test]
    gold = [x[1] for x in preds_test]
    test_f1s[model] = compute_micro_f1_tacred(pred, gold)
    
test_f1s
# Out:
# {'LUKE': 0.7205131943431987,
#  'SpanBERT': 0.43071613459879204,
#  'SURE': 0.7484536082474227,
#  'TYP_marker': 0.7208764079617342,
#  'UniST': 0.703357350912157,
#  'NLI_w': 0.6861173453029816,
#  'NLI_wo': 0.4272930648769575}

# %%
model = 'NLI_wo'
correct_rels = [x['correct_relation'] for x in data['test.json']]
predicted = [x['results'][model] for x in data['test.json']]
compute_micro_f1_tacred(predicted, correct_rels)
# Out:
# 0.4272930648769575

# %%
no_relations = {
    m : {
        x : 0 for x in glob.glob(f'./models/{m}/*.json')
    }
    for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']
}
l = len(predictions['SURE'])
for model in no_relations:
    for x in no_relations[model]:
        model_predictions = json.load(open(x))
        predicted_no_rels = len([sen for sen in model_predictions if sen[0]=='no_relation' or sen[0]=='no relation'])
        actual_no_rels = len([sen for sen in model_predictions if sen[1]=='no_relation' or sen[1]=='no relation'])
        diff = predicted_no_rels - actual_no_rels
        diff_perc = diff * 100 / actual_no_rels
        no_relations[model][x] = diff_perc
no_relations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d13266af7466> in <module>
#       5     for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']
#       6 }
# ----> 7 l = len(predictions['SURE'])
#       8 for model in no_relations:
#       9     for x in no_relations[model]:
#
# NameError: name 'predictions' is not defined

# %%
controlled = 0
model = 'CNN'
for i, file in enumerate(sorted(list(data.keys()))):
    print(file)
    sentences = data[file] if 'controlled' in file else data[file]
    preds = [sentence['results'][model] for sentence in sentences]
    gold = [sentence['correct_relation'] for sentence in sentences]
    f1 = compute_micro_f1_tacred(gold, preds)*100
    print(f1)
    if 'controlled' in file:
        controlled += f1
    else:
        test_f1 = f1
    if (i+1) % 3 == 0:
        print('-----')
print('######')
avg_controlled = controlled / 12
loss = (test_f1 - avg_controlled)*100/test_f1
print(f"average controlled: {avg_controlled}")
print(f"percentage loss: {loss}")

# %%
controlled = 0
model = 'CNN'
test_f1 = 0
data_file = {file : json.load(open(file)) for file in glob.glob(f'./models/{model}/*')}
for i, file in enumerate(sorted(list(data_file.keys()))):
    sentences = data_file[file]
    preds = [sentence[0] for sentence in sentences]
    gold = [sentence[1] for sentence in sentences]
    f1 = compute_micro_f1_tacred(gold, preds)*100
    print(file, f1)
    if 'controlled' in file:
        controlled += f1
    else:
        test_f1 = f1
    if (i+1) % 3 == 0:
        print('-----')
print('######')
avg_controlled = controlled / 12
loss = (test_f1 - avg_controlled)*100/test_f1
print(f"average controlled: {avg_controlled}")
print(f"percentage loss: {loss}")

# %%
x = json.load(open('./models/LUKE/test.json'))
len(x)
# Out:
# 15509

# %%
y = json.load(open('./models/LUKE/controlled_tacred_test_sub1_obj.json'))
len(y)
# Out:
# 5102

# %%
15509 - 5102
# Out:
# 10407

# %%
percentages = {
    m : {
        d : [0,0] for d in data
        if 'controlled' in d#(correctly predicted, actual total)
    }
    for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']
}
predictions = {
    m : {}
    for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']
}
heatmap_source = {
    m : {
    }
    for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']
}
predictions['correct'] = {}

# %%
adversarial_wise_pred = {
    adv : {
        m : {}
        for m in data['controlled_tacred_test_sub1_obj.json'][0]['results']
    }
    for adv in data
    if 'controlled' in adv
}
all_rels_count = {}

# %%
for file in [x for x in data if 'controlled' in x]:
    for sentence in data[file]:
        gold_rel = sentence['correct_relation']
        if gold_rel not in all_rels_count:
            all_rels_count[gold_rel] = 0
        all_rels_count[gold_rel] += 1
        if gold_rel not in predictions['correct']:
            predictions['correct'][gold_rel] = 0
        for model in heatmap_source:
            if gold_rel not in heatmap_source[model]:
                heatmap_source[model][gold_rel] = {}
                for adv in adversarial_wise_pred:
                    adversarial_wise_pred[adv][model][gold_rel] = {'total':0, 'correct':0}
        predictions['correct'][gold_rel] += 1

# %%
for d in tqdm.tqdm([x for x in data if 'controlled' in x]):
    file = data[d]
    for sentence in file:
        correct_rel = sentence['correct_relation']
        possible_rels = sentence['relation_per_types']
        for model in sentence['results']:
            adversarial_wise_pred[d][model][correct_rel]['total'] += 1
            percentages[model][d][1] += 1
            predicted = sentence['results'][model]
            if predicted not in predictions[model]:
                predictions[model][predicted] = 0
            if predicted not in heatmap_source[model][correct_rel]:
                heatmap_source[model][correct_rel][predicted] = 0
            heatmap_source[model][correct_rel][predicted] += 1
            predictions[model][predicted] +=1
            if predicted in possible_rels:
                percentages[model][d][0] +=1
            if correct_rel == predicted:
                adversarial_wise_pred[d][model][correct_rel]['correct'] += 1
# Out:
# 100%|██████████| 12/12 [00:01<00:00,  7.15it/s]

# %%
models_to_name = {
 'LUKE' : 'LUKE',
 'NLI_wo' : 'NLI (w/o)',
 'SpanBERT' : 'SpanBERT',
 'TYP_marker' : 'TYP-marker',
 'CNN' : 'CNN',
 'SURE' : 'SuRE',
 'NLI_w' : 'NLI (w/)',
 'UniST' : 'UniST',
 'correct' : 'correct'
}
subst_to_name = {
    'sub1_subj' : 'same-role subj',
     'sub1_obj' : 'same-role obj',
    'sub1_subj+obj': 'same-role subj+obj',
     'sub2_subj' : 'same-type subj',
     'sub2_obj' : 'same-type obj',
     'sub2_subj+obj' : 'same-type subj+obj',
     'sub3_subj' : 'diff.-type subj',
     'sub3_obj' : 'diff.-type obj',
     'sub3_subj+obj' : 'diff.-type subj+obj',
     'sub4_subj' : 'masked subj',
     'sub4_obj' : 'masked obj',
     'sub4_subj+obj' : 'masked subj+obj'
}

# %%
import regex as re
from altair.expr import datum


pattern = r'sub[0-9]\_[a-z+]*'

percentages_values = [
    [
        models_to_name[m],
        subst_to_name[re.findall(pattern, d)[0]],
        round(percentages[m][d][0] / percentages[m][d][1] * 100, 2)]
    for m in percentages
    for d in percentages[m]
    if 'controlled' in d
]

correct_preds = {}
for k in predictions:
    correct_preds[models_to_name[k]] = predictions[k]

# %%
source = pd.DataFrame(percentages_values, columns=['model', 'substitution', 'percentage'])

# %%
sort = [
    'sub1_subj',
     'sub1_obj',
    'sub1_subj+obj',
     'sub2_subj',
     'sub2_obj',
     'sub2_subj+obj',
     'sub3_subj',
     'sub3_obj',
     'sub3_subj+obj',
     'sub4_subj',
     'sub4_obj',
     'sub4_subj+obj'
]
sort = [subst_to_name[s] for s in sort]

# %%
heatmap = alt.Chart(source).mark_rect().encode(
    y= alt.Y('model:N', title=""),
    x=alt.X('substitution:N', sort=sort, axis=alt.Axis(labelAngle=-45), title=""),
    color=alt.Color('percentage:Q', legend=None, scale=alt.Scale(scheme='lighttealblue'))
).properties(
    width=500,
    height=350
)

text = alt.Chart(source).mark_text(baseline='middle', fontSize=14).encode(
    y='model:N',
    x=alt.X('substitution:N', sort=sort, axis=alt.Axis(labelAngle=-45)),
    text='percentage:Q',
    color=alt.condition(datum['percentage'] < 30,
                        alt.value('grey'),
                        alt.value('white'))
)

rule1 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=2.2).encode(x=alt.value(125))
rule2 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=2.2).encode(x=alt.value(250))
rule3 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=2.2).encode(x=alt.value(375))
rule4 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(44))
rule5 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(87))
rule6 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(130))
rule7 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(43))
rule8 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(43))
rule9 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(43))
rule10 = alt.Chart(source).mark_rule(stroke='white',strokeWidth=0.05).encode(y=alt.value(43))

alt.layer(heatmap, text,rule1,rule2,rule3).configure_view(
    stroke='transparent'
).configure_axis(
    domainWidth=0.8
).configure_axis(
    labelFontSize=15,
    titleFontSize=12
)
#heatmap + text + rule1
# Out:
# alt.LayerChart(...)

# %%
all_relations = json.load(open('./rel2types.json'))
all_relations = list(all_relations.keys()) + ['no_relation']

total = sum([predictions['correct'][x] for x in predictions['correct']])
predictions_source = [
    [
        model,
        relation,
        predictions[model].get(relation,0),
        predictions['correct'].get(relation,0),
        (predictions[model].get(relation,0)/total)-(predictions['correct'].get(relation,0)/total)
    ]
                      for model in predictions
                      for relation in all_relations]
predictions_source = pd.DataFrame(predictions_source, columns=['model', 'relation', 'predicted', 'correct', 'difference'])

# %%
df = []
for model in heatmap_source:
    for relation in heatmap_source[model]: 
        total = sum([heatmap_source[model][relation][r2] for r2 in heatmap_source[model][relation]])
        for relation2 in all_relations:
            row = [model, relation, relation2, heatmap_source[model][relation].get(relation2, 0)/total*100]
            df.append(row)
        
df = pd.DataFrame(df, columns=['model','correct', 'predicted', 'count'])

# %%
all_charts =  [
    alt.Chart(df[df['model'] == m]).mark_rect().encode(
    x=alt.X('predicted:N', axis=alt.Axis(labelAngle=-45)),
    y='correct:N',
    color=alt.Color('count:Q',scale=alt.Scale(scheme='lightgreyteal'))
).properties(
    width=410,
    height=300,
    title=m
)
for m in list(set(df['model']))]

# %%
base = alt.Chart(df).mark_rect().encode(
    x='correct:N',
    y='predicted:N',
    color='count:Q'
).properties(
    width=160,
    height=160
)

# %%
models = list(set(predictions_source['model']))

# %%
def kl_divergence(p,q):
    return sum(p[i] * math.log2(p[i]/(q[i]+0.001)) for i in range(len(p)))

# %%
all_rels_sorted = [k[0] for k in sorted(all_rels_count.items(), key= lambda k:k[1], reverse=True)]

# %%
def plot_pred(model):
    source = predictions_source[
        ((predictions_source['model'] == model) |
        (predictions_source['model'] == 'correct')) &
        (predictions_source['relation'] != 'no_relation')
    ]
    source['model'] = ['actual' if x == 'correct' else 'predicted' for x in source['model']]
    p = list(source['correct'])
    q = list(source['predicted'])
    tots = sum(p)
    p = [n/tots for n in p]
    q = [n/tots for n in q]
    subt = round(scipy.stats.entropy(p,q), 2)
    chart = alt.Chart(source).mark_line().encode(
        y= alt.Y('predicted:Q', title=""),
        x = alt.X('relation:N', axis=alt.Axis(labelAngle=-45), title="", sort=all_rels_sorted),
        strokeDash = alt.StrokeDash('model:N', legend=alt.Legend(title='')),
        color=alt.Color('model:N'),
    ).properties(
        width=600,
        height=250,
        title={
            "text" : [model],
            #"subtitle" : [f"DIVERGENCE: {str(subt)}"]
        }
    )
    return chart

# %%
all_charts = [plot_pred(m) for m in models if m != 'correct']
alt.vconcat(
    (all_charts[1]|all_charts[2]),
    (all_charts[3]|all_charts[4]),
    (all_charts[5]|all_charts[6]),
    (all_charts[0]),
)
# Out:
# /home/gennaronolano/anaconda3/envs/general_nlp/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# alt.VConcatChart(...)

# %%
source_correct = predictions_source[
    (predictions_source['relation'] != 'no_relation') & (predictions_source['model']=='correct')
]
source_all = predictions_source[
    (predictions_source['relation'] != 'no_relation') & (predictions_source['model'] != 'correct')
]
chart = alt.Chart(source_correct).mark_line().encode(
    y= alt.Y('predicted:Q', title=""),
    x = alt.X('relation:N', axis=alt.Axis(labelAngle=-45), title="", sort=all_rels_sorted),
    #strokeDash = alt.StrokeDash('model:N', legend=alt.Legend(title='')),
    color=alt.Color('model:N'),
).properties(
    width=600,
    height=250,
    title={
        "text" : [model],
        #"subtitle" : [f"DIVERGENCE: {str(subt)}"]
    }
)
plot = alt.Chart(source_all).mark_circle(size=60).encode(
    x = alt.X('relation:N', axis=alt.Axis(labelAngle=-45), title="", sort=all_rels_sorted),
    y = alt.Y('predicted:Q', title=""),
    color=alt.Color('model:N')
)
chart+plot
# Out:
# alt.LayerChart(...)

# %%
div_avg = (.43 + .13 + .13 + .25 + .26 + .36 + .16) / 7
div_avg
# Out:
# 0.24571428571428572

# %%
for adv in adversarial_wise_pred:
    for model in adversarial_wise_pred[adv]:
        for relation in adversarial_wise_pred[adv][model]:
            adversarial_wise_pred[adv][model][relation]['percentage'] = adversarial_wise_pred[adv][model][relation]['correct'] / adversarial_wise_pred[adv][model][relation]['total'] * 100

# %%
pattern = r'sub[0-9]\_[a-z+]*'

df = []
for adv in adversarial_wise_pred:
    adv_str = subst_to_name[re.findall(pattern,adv)[0]]
    for model in adversarial_wise_pred[adv]:
        for rel in adversarial_wise_pred[adv][model]:
            row = [adv_str, model, rel, adversarial_wise_pred[adv][model][rel]['percentage']]
            df.append(row)
df = pd.DataFrame(df, columns = ['adversarial','model', 'relation','percentage'])

# %%
all_charts =  [
    alt.Chart(df[df['adversarial'] == m]).mark_rect().encode(
    y=alt.Y('model:N', axis=alt.Axis(labelAngle=-0)),
    x=alt.X('relation:N', axis=alt.Axis(labelAngle=-45)),
    color=alt.Color('percentage:Q',scale=alt.Scale(scheme='lightgreyteal'))
).properties(
    width=500,
    height=100,
    title=m
)
for m in sort]

# %%
alt.vconcat(
    (all_charts[0]|all_charts[1]|all_charts[2]),
    (all_charts[3]|all_charts[4]|all_charts[5]),
    (all_charts[6]|all_charts[7]|all_charts[8]),
    (all_charts[9]|all_charts[10]|all_charts[11]),

)
# Out:
# alt.VConcatChart(...)

# %%
heatmap_source
# Out:
# {'LUKE': {'no_relation': {'no_relation': 41122,
#    'org:top_members/employees': 441,
#    'per:cities_of_residence': 210,
#    'per:title': 201,
#    'per:employee_of': 526,
#    'per:alternate_names': 44,
#    'per:other_family': 83,
#    'org:parents': 118,
#    'per:children': 38,
#    'per:spouse': 86,
#    'org:alternate_names': 252,
#    'per:countries_of_residence': 89,
#    'org:city_of_headquarters': 120,
#    'org:member_of': 3,
#    'per:charges': 47,
#    'per:siblings': 65,
#    'org:shareholders': 42,
#    'org:founded_by': 28,
#    'per:parents': 51,
#    'org:members': 12,
#    'per:origin': 28,
#    'per:cause_of_death': 28,
#    'org:stateorprovince_of_headquarters': 42,
#    'org:subsidiaries': 29,
#    'per:stateorprovinces_of_residence': 63,
#    'org:country_of_headquarters': 81,
#    'per:age': 6,
#    'per:city_of_death': 17,
#    'per:schools_attended': 15,
#    'org:political/religious_affiliation': 5,
#    'org:dissolved': 20,
#    'per:date_of_death': 50,
#    'per:stateorprovince_of_death': 5,
#    'per:religion': 12,
#    'org:founded': 1},
#   'per:title': {'no_relation': 894,
#    'per:title': 1434,
#    'per:employee_of': 255,
#    'per:origin': 13,
#    'per:alternate_names': 28,
#    'per:stateorprovinces_of_residence': 8,
#    'per:siblings': 4,
#    'org:top_members/employees': 10,
#    'org:stateorprovince_of_headquarters': 3,
#    'per:cities_of_residence': 14,
#    'per:religion': 2,
#    'per:age': 1,
#    'per:schools_attended': 2,
#    'org:founded_by': 2,
#    'org:members': 1,
#    'org:city_of_headquarters': 1,
#    'per:other_family': 1,
#    'per:countries_of_residence': 1,
#    'org:alternate_names': 2},
#   'org:top_members/employees': {'org:top_members/employees': 1946,
#    'no_relation': 474,
#    'org:founded_by': 39,
#    'per:employee_of': 8,
#    'org:alternate_names': 51,
#    'per:title': 7,
#    'org:country_of_headquarters': 1,
#    'org:founded': 1,
#    'org:subsidiaries': 3,
#    'org:city_of_headquarters': 1,
#    'org:parents': 1},
#   'org:country_of_headquarters': {'no_relation': 672,
#    'org:city_of_headquarters': 23,
#    'org:parents': 14,
#    'org:country_of_headquarters': 203,
#    'org:stateorprovince_of_headquarters': 13,
#    'org:alternate_names': 23,
#    'per:countries_of_residence': 6,
#    'org:top_members/employees': 4,
#    'org:member_of': 1,
#    'per:employee_of': 1},
#   'per:parents': {'per:parents': 309,
#    'no_relation': 122,
#    'per:children': 5,
#    'per:other_family': 11,
#    'per:siblings': 5,
#    'per:employee_of': 1,
#    'org:top_members/employees': 3},
#   'per:age': {'per:age': 17,
#    'no_relation': 26,
#    'per:origin': 4,
#    'per:employee_of': 1},
#   'per:countries_of_residence': {'no_relation': 589,
#    'per:countries_of_residence': 249,
#    'per:origin': 33,
#    'per:employee_of': 57,
#    'per:cities_of_residence': 15,
#    'per:title': 9,
#    'org:country_of_headquarters': 8,
#    'per:stateorprovinces_of_residence': 5,
#    'per:religion': 1,
#    'org:parents': 2,
#    'org:alternate_names': 1,
#    'per:alternate_names': 3},
#   'per:children': {'per:children': 73,
#    'no_relation': 24,
#    'per:parents': 11,
#    'per:spouse': 10,
#    'per:employee_of': 1,
#    'per:siblings': 1},
#   'org:alternate_names': {'no_relation': 511,
#    'org:alternate_names': 492,
#    'org:country_of_headquarters': 2,
#    'org:subsidiaries': 11,
#    'org:city_of_headquarters': 4,
#    'org:parents': 1,
#    'per:title': 1,
#    'per:employee_of': 5,
#    'org:member_of': 1,
#    'per:alternate_names': 1,
#    'org:top_members/employees': 2,
#    'org:founded_by': 1},
#   'per:charges': {'per:charges': 111, 'no_relation': 67, 'per:employee_of': 2},
#   'per:cities_of_residence': {'per:cities_of_residence': 593,
#    'per:employee_of': 80,
#    'per:city_of_death': 6,
#    'no_relation': 458,
#    'org:city_of_headquarters': 25,
#    'per:stateorprovinces_of_residence': 10,
#    'per:stateorprovince_of_death': 1,
#    'per:countries_of_residence': 18,
#    'per:city_of_birth': 8,
#    'per:origin': 6,
#    'per:religion': 3,
#    'per:schools_attended': 2,
#    'org:alternate_names': 1,
#    'org:country_of_headquarters': 1},
#   'per:origin': {'per:origin': 81,
#    'per:countries_of_residence': 78,
#    'no_relation': 218,
#    'per:employee_of': 38,
#    'per:cities_of_residence': 18,
#    'per:stateorprovinces_of_residence': 4,
#    'org:country_of_headquarters': 10,
#    'per:title': 4,
#    'per:charges': 1,
#    'org:top_members/employees': 1,
#    'org:city_of_headquarters': 1,
#    'per:alternate_names': 1,
#    'per:city_of_birth': 1},
#   'org:founded_by': {'no_relation': 86,
#    'org:founded_by': 115,
#    'org:top_members/employees': 31,
#    'org:country_of_headquarters': 1,
#    'per:siblings': 2,
#    'org:subsidiaries': 2,
#    'org:founded': 1,
#    'per:title': 1,
#    'per:employee_of': 1},
#   'per:employee_of': {'per:employee_of': 959,
#    'no_relation': 530,
#    'per:cities_of_residence': 34,
#    'per:origin': 3,
#    'org:top_members/employees': 11,
#    'per:stateorprovinces_of_residence': 2,
#    'per:title': 14,
#    'per:countries_of_residence': 3,
#    'org:parents': 5,
#    'per:schools_attended': 1,
#    'org:political/religious_affiliation': 1,
#    'org:alternate_names': 18,
#    'org:city_of_headquarters': 2,
#    'per:alternate_names': 1},
#   'per:siblings': {'per:siblings': 216,
#    'no_relation': 79,
#    'per:other_family': 2,
#    'per:title': 1,
#    'per:employee_of': 1,
#    'org:founded_by': 1},
#   'per:alternate_names': {'no_relation': 56,
#    'per:alternate_names': 13,
#    'per:employee_of': 1,
#    'org:alternate_names': 1,
#    'per:origin': 1},
#   'per:religion': {'per:religion': 35,
#    'no_relation': 70,
#    'per:employee_of': 6,
#    'org:political/religious_affiliation': 6,
#    'per:title': 1,
#    'org:city_of_headquarters': 1,
#    'org:alternate_names': 1},
#   'per:stateorprovince_of_death': {'per:stateorprovince_of_death': 22,
#    'no_relation': 66,
#    'per:stateorprovinces_of_residence': 11,
#    'per:city_of_death': 7,
#    'per:cities_of_residence': 1,
#    'per:charges': 1},
#   'org:parents': {'org:parents': 178,
#    'no_relation': 249,
#    'org:country_of_headquarters': 5,
#    'org:city_of_headquarters': 2,
#    'org:top_members/employees': 1,
#    'org:alternate_names': 8,
#    'org:member_of': 1,
#    'org:subsidiaries': 3,
#    'org:shareholders': 7,
#    'per:employee_of': 2},
#   'org:subsidiaries': {'org:subsidiaries': 109,
#    'no_relation': 203,
#    'org:parents': 20,
#    'org:stateorprovince_of_headquarters': 1,
#    'org:alternate_names': 9,
#    'per:employee_of': 5,
#    'org:top_members/employees': 1},
#   'per:other_family': {'per:other_family': 226,
#    'no_relation': 77,
#    'per:parents': 6,
#    'per:countries_of_residence': 1,
#    'per:employee_of': 1,
#    'org:top_members/employees': 1},
#   'per:stateorprovinces_of_residence': {'no_relation': 272,
#    'org:stateorprovince_of_headquarters': 13,
#    'per:stateorprovinces_of_residence': 137,
#    'per:countries_of_residence': 7,
#    'per:cities_of_residence': 27,
#    'per:employee_of': 28,
#    'per:city_of_death': 3,
#    'per:other_family': 1,
#    'per:siblings': 1,
#    'per:title': 2,
#    'org:top_members/employees': 1},
#   'org:members': {'no_relation': 113,
#    'org:city_of_headquarters': 1,
#    'org:subsidiaries': 7,
#    'org:members': 4,
#    'org:top_members/employees': 1,
#    'org:alternate_names': 2,
#    'per:title': 1,
#    'per:religion': 1,
#    'per:employee_of': 2},
#   'per:cause_of_death': {'per:cause_of_death': 44,
#    'no_relation': 63,
#    'per:title': 1},
#   'org:member_of': {'org:parents': 19,
#    'no_relation': 96,
#    'org:member_of': 1,
#    'org:country_of_headquarters': 4},
#   'per:country_of_birth': {'per:countries_of_residence': 7,
#    'no_relation': 25,
#    'per:stateorprovinces_of_residence': 3,
#    'per:title': 1},
#   'org:shareholders': {'no_relation': 83,
#    'org:parents': 19,
#    'org:founded_by': 2,
#    'org:top_members/employees': 2,
#    'org:alternate_names': 2},
#   'org:stateorprovince_of_headquarters': {'no_relation': 171,
#    'org:stateorprovince_of_headquarters': 126,
#    'org:parents': 6,
#    'org:city_of_headquarters': 28,
#    'per:stateorprovinces_of_residence': 3,
#    'per:title': 1,
#    'org:country_of_headquarters': 2,
#    'org:founded_by': 1,
#    'org:top_members/employees': 1,
#    'per:employee_of': 1,
#    'org:alternate_names': 8},
#   'per:city_of_death': {'no_relation': 134,
#    'per:city_of_death': 53,
#    'per:city_of_birth': 9,
#    'per:cities_of_residence': 11,
#    'per:stateorprovince_of_death': 5,
#    'per:stateorprovinces_of_residence': 1,
#    'per:cause_of_death': 1,
#    'org:city_of_headquarters': 2},
#   'per:date_of_birth': {'per:date_of_birth': 8, 'no_relation': 16},
#   'per:spouse': {'per:spouse': 216,
#    'no_relation': 82,
#    'per:employee_of': 1,
#    'org:top_members/employees': 1},
#   'org:city_of_headquarters': {'org:city_of_headquarters': 232,
#    'no_relation': 285,
#    'org:parents': 2,
#    'org:country_of_headquarters': 4,
#    'org:alternate_names': 11,
#    'org:stateorprovince_of_headquarters': 5,
#    'org:subsidiaries': 10,
#    'per:employee_of': 1,
#    'per:cities_of_residence': 2},
#   'per:date_of_death': {'no_relation': 139,
#    'per:date_of_death': 124,
#    'per:cause_of_death': 1},
#   'per:schools_attended': {'no_relation': 79,
#    'per:schools_attended': 34,
#    'per:stateorprovinces_of_residence': 1,
#    'per:cities_of_residence': 1,
#    'per:employee_of': 17},
#   'per:country_of_death': {'no_relation': 85,
#    'per:countries_of_residence': 10,
#    'per:stateorprovinces_of_residence': 1},
#   'org:founded': {'org:founded': 10,
#    'no_relation': 13,
#    'org:city_of_headquarters': 1},
#   'per:stateorprovince_of_birth': {'per:stateorprovince_of_birth': 9,
#    'per:stateorprovinces_of_residence': 16,
#    'no_relation': 11},
#   'per:city_of_birth': {'per:cities_of_residence': 30,
#    'per:stateorprovince_of_birth': 3,
#    'per:city_of_birth': 12,
#    'no_relation': 3},
#   'org:dissolved': {'no_relation': 14,
#    'org:dissolved': 8,
#    'org:alternate_names': 2}},
#  'SpanBERT': {'no_relation': {'no_relation': 41946,
#    'per:date_of_death': 37,
#    'org:top_members/employees': 277,
#    'per:title': 152,
#    'per:religion': 158,
#    'per:origin': 45,
#    'org:founded_by': 27,
#    'per:other_family': 80,
#    'per:spouse': 149,
#    'per:cities_of_residence': 162,
#    'org:members': 8,
#    'org:alternate_names': 180,
#    'per:city_of_death': 22,
#    'org:political/religious_affiliation': 112,
#    'per:date_of_birth': 3,
#    'per:siblings': 38,
#    'per:parents': 36,
#    'per:charges': 32,
#    'per:cause_of_death': 5,
#    'per:alternate_names': 82,
#    'per:stateorprovinces_of_residence': 34,
#    'per:children': 16,
#    'per:age': 37,
#    'org:website': 60,
#    'per:employee_of': 63,
#    'per:countries_of_residence': 30,
#    'org:city_of_headquarters': 88,
#    'org:parents': 25,
#    'org:country_of_headquarters': 13,
#    'org:founded': 14,
#    'org:subsidiaries': 8,
#    'per:stateorprovince_of_death': 11,
#    'per:schools_attended': 9,
#    'org:member_of': 5,
#    'org:stateorprovince_of_headquarters': 11,
#    'per:stateorprovince_of_birth': 1,
#    'per:city_of_birth': 4},
#   'per:title': {'per:title': 1399,
#    'no_relation': 892,
#    'per:alternate_names': 163,
#    'per:cities_of_residence': 105,
#    'per:origin': 17,
#    'per:age': 41,
#    'per:religion': 13,
#    'org:alternate_names': 6,
#    'per:spouse': 3,
#    'per:stateorprovinces_of_residence': 4,
#    'per:schools_attended': 1,
#    'org:top_members/employees': 16,
#    'per:employee_of': 2,
#    'per:date_of_death': 1,
#    'org:political/religious_affiliation': 3,
#    'org:city_of_headquarters': 2,
#    'org:website': 1,
#    'org:members': 1,
#    'per:city_of_death': 3,
#    'per:charges': 1,
#    'per:siblings': 1,
#    'per:cause_of_death': 1},
#   'org:top_members/employees': {'org:top_members/employees': 1494,
#    'no_relation': 933,
#    'org:founded_by': 26,
#    'org:city_of_headquarters': 12,
#    'org:alternate_names': 12,
#    'org:website': 1,
#    'per:alternate_names': 12,
#    'per:employee_of': 25,
#    'per:stateorprovinces_of_residence': 1,
#    'per:parents': 2,
#    'org:political/religious_affiliation': 1,
#    'org:subsidiaries': 3,
#    'org:country_of_headquarters': 1,
#    'per:religion': 2,
#    'per:age': 2,
#    'per:countries_of_residence': 1,
#    'per:origin': 1,
#    'per:cities_of_residence': 2,
#    'per:title': 1},
#   'org:country_of_headquarters': {'no_relation': 695,
#    'org:website': 136,
#    'org:political/religious_affiliation': 56,
#    'org:top_members/employees': 8,
#    'org:city_of_headquarters': 46,
#    'org:country_of_headquarters': 4,
#    'org:founded': 7,
#    'per:age': 2,
#    'org:members': 1,
#    'org:subsidiaries': 1,
#    'org:alternate_names': 2,
#    'org:member_of': 1,
#    'per:schools_attended': 1},
#   'per:parents': {'per:parents': 316,
#    'no_relation': 128,
#    'per:city_of_birth': 4,
#    'per:origin': 1,
#    'org:founded_by': 1,
#    'per:other_family': 2,
#    'per:cities_of_residence': 2,
#    'per:children': 1,
#    'per:alternate_names': 1},
#   'per:age': {'per:city_of_birth': 4,
#    'per:employee_of': 4,
#    'no_relation': 20,
#    'per:countries_of_residence': 1,
#    'per:age': 2,
#    'per:cities_of_residence': 8,
#    'per:stateorprovinces_of_residence': 1,
#    'per:stateorprovince_of_death': 1,
#    'per:alternate_names': 4,
#    'per:origin': 1,
#    'org:alternate_names': 1,
#    'org:city_of_headquarters': 1},
#   'per:countries_of_residence': {'no_relation': 682,
#    'per:charges': 43,
#    'per:religion': 95,
#    'per:age': 7,
#    'per:cities_of_residence': 60,
#    'org:website': 38,
#    'per:date_of_death': 8,
#    'per:employee_of': 12,
#    'per:date_of_birth': 2,
#    'per:stateorprovinces_of_residence': 6,
#    'per:origin': 5,
#    'per:city_of_death': 1,
#    'per:countries_of_residence': 3,
#    'org:political/religious_affiliation': 3,
#    'org:city_of_headquarters': 2,
#    'org:founded': 1,
#    'org:top_members/employees': 3,
#    'per:city_of_birth': 1},
#   'per:children': {'no_relation': 33,
#    'per:children': 36,
#    'per:parents': 37,
#    'per:spouse': 11,
#    'org:subsidiaries': 1,
#    'per:city_of_birth': 1,
#    'per:city_of_death': 1},
#   'org:alternate_names': {'org:alternate_names': 416,
#    'no_relation': 533,
#    'org:website': 1,
#    'org:country_of_headquarters': 3,
#    'org:founded': 16,
#    'org:top_members/employees': 7,
#    'org:shareholders': 11,
#    'org:political/religious_affiliation': 1,
#    'per:alternate_names': 22,
#    'per:title': 1,
#    'org:member_of': 1,
#    'org:city_of_headquarters': 14,
#    'per:age': 3,
#    'per:origin': 1,
#    'org:founded_by': 2},
#   'per:charges': {'no_relation': 75, 'per:charges': 105},
#   'per:cities_of_residence': {'no_relation': 657,
#    'per:age': 12,
#    'per:religion': 309,
#    'per:cities_of_residence': 123,
#    'per:stateorprovinces_of_residence': 37,
#    'per:city_of_death': 8,
#    'per:origin': 9,
#    'per:cause_of_death': 1,
#    'per:stateorprovince_of_death': 7,
#    'per:alternate_names': 6,
#    'per:date_of_death': 5,
#    'org:stateorprovince_of_headquarters': 2,
#    'org:political/religious_affiliation': 20,
#    'per:date_of_birth': 1,
#    'per:countries_of_residence': 2,
#    'per:children': 2,
#    'per:employee_of': 1,
#    'org:country_of_headquarters': 1,
#    'org:city_of_headquarters': 3,
#    'org:website': 1,
#    'org:members': 1,
#    'org:top_members/employees': 2,
#    'per:city_of_birth': 1,
#    'per:spouse': 1},
#   'per:origin': {'per:cities_of_residence': 50,
#    'per:religion': 64,
#    'no_relation': 225,
#    'per:age': 10,
#    'org:website': 38,
#    'per:origin': 14,
#    'per:charges': 18,
#    'per:employee_of': 4,
#    'per:countries_of_residence': 3,
#    'per:cause_of_death': 4,
#    'per:stateorprovinces_of_residence': 3,
#    'per:alternate_names': 11,
#    'per:title': 4,
#    'per:date_of_death': 2,
#    'org:member_of': 1,
#    'org:political/religious_affiliation': 1,
#    'per:city_of_death': 1,
#    'org:top_members/employees': 2,
#    'org:founded_by': 1},
#   'org:founded_by': {'no_relation': 117,
#    'org:founded_by': 98,
#    'org:top_members/employees': 5,
#    'org:website': 2,
#    'org:parents': 3,
#    'per:parents': 4,
#    'per:employee_of': 1,
#    'per:spouse': 3,
#    'per:schools_attended': 1,
#    'org:city_of_headquarters': 6},
#   'per:employee_of': {'no_relation': 1314,
#    'org:top_members/employees': 105,
#    'per:date_of_death': 7,
#    'per:age': 27,
#    'per:origin': 7,
#    'per:employee_of': 9,
#    'per:cities_of_residence': 59,
#    'per:religion': 29,
#    'per:charges': 5,
#    'per:title': 8,
#    'per:countries_of_residence': 1,
#    'per:stateorprovinces_of_residence': 1,
#    'org:founded_by': 5,
#    'org:political/religious_affiliation': 2,
#    'org:number_of_employees/members': 1,
#    'per:city_of_death': 1,
#    'per:alternate_names': 3},
#   'per:siblings': {'per:siblings': 188,
#    'no_relation': 101,
#    'per:other_family': 11},
#   'per:alternate_names': {'no_relation': 36,
#    'per:alternate_names': 33,
#    'org:alternate_names': 2,
#    'per:religion': 1},
#   'per:religion': {'per:age': 6,
#    'no_relation': 80,
#    'per:religion': 9,
#    'per:title': 2,
#    'org:top_members/employees': 4,
#    'per:origin': 6,
#    'per:alternate_names': 3,
#    'org:political/religious_affiliation': 4,
#    'per:cities_of_residence': 6},
#   'per:stateorprovince_of_death': {'per:stateorprovince_of_death': 16,
#    'no_relation': 73,
#    'per:city_of_death': 7,
#    'per:date_of_death': 7,
#    'per:religion': 1,
#    'per:spouse': 3,
#    'per:origin': 1},
#   'org:parents': {'no_relation': 398,
#    'org:political/religious_affiliation': 8,
#    'org:website': 3,
#    'org:subsidiaries': 18,
#    'org:shareholders': 8,
#    'org:parents': 2,
#    'org:founded': 2,
#    'org:top_members/employees': 4,
#    'org:city_of_headquarters': 11,
#    'org:country_of_headquarters': 2},
#   'org:subsidiaries': {'no_relation': 312,
#    'org:subsidiaries': 17,
#    'org:political/religious_affiliation': 2,
#    'org:parents': 2,
#    'per:cities_of_residence': 2,
#    'org:city_of_headquarters': 5,
#    'org:alternate_names': 2,
#    'org:website': 1,
#    'org:founded_by': 1,
#    'org:shareholders': 3,
#    'org:top_members/employees': 1},
#   'per:other_family': {'per:other_family': 155,
#    'no_relation': 155,
#    'per:parents': 2},
#   'per:stateorprovinces_of_residence': {'no_relation': 324,
#    'org:website': 1,
#    'per:city_of_death': 10,
#    'per:countries_of_residence': 6,
#    'per:stateorprovinces_of_residence': 22,
#    'per:religion': 50,
#    'org:political/religious_affiliation': 6,
#    'per:origin': 4,
#    'per:cities_of_residence': 41,
#    'per:age': 18,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:stateorprovince_of_death': 4,
#    'per:title': 1,
#    'per:alternate_names': 1,
#    'org:city_of_headquarters': 2,
#    'per:spouse': 1},
#   'org:members': {'no_relation': 113,
#    'org:website': 10,
#    'org:alternate_names': 2,
#    'org:members': 2,
#    'org:stateorprovince_of_headquarters': 1,
#    'org:city_of_headquarters': 3,
#    'org:founded': 1},
#   'per:cause_of_death': {'no_relation': 74,
#    'per:cause_of_death': 30,
#    'per:date_of_death': 4},
#   'org:member_of': {'org:members': 15,
#    'no_relation': 90,
#    'org:political/religious_affiliation': 6,
#    'per:employee_of': 1,
#    'org:parents': 1,
#    'org:shareholders': 1,
#    'org:city_of_headquarters': 6},
#   'per:country_of_birth': {'per:religion': 5,
#    'no_relation': 27,
#    'org:website': 1,
#    'per:cities_of_residence': 3},
#   'org:shareholders': {'no_relation': 95,
#    'org:shareholders': 6,
#    'org:website': 3,
#    'per:religion': 1,
#    'per:title': 1,
#    'org:city_of_headquarters': 2},
#   'org:stateorprovince_of_headquarters': {'no_relation': 215,
#    'org:founded': 7,
#    'org:stateorprovince_of_headquarters': 14,
#    'org:political/religious_affiliation': 44,
#    'org:number_of_employees/members': 3,
#    'org:city_of_headquarters': 43,
#    'org:website': 2,
#    'org:alternate_names': 1,
#    'per:stateorprovince_of_birth': 1,
#    'per:spouse': 1,
#    'per:stateorprovince_of_death': 1,
#    'per:stateorprovinces_of_residence': 4,
#    'per:religion': 3,
#    'org:country_of_headquarters': 4,
#    'org:parents': 1,
#    'per:cities_of_residence': 1,
#    'org:founded_by': 2,
#    'per:age': 1},
#   'per:city_of_death': {'no_relation': 125,
#    'per:stateorprovince_of_death': 16,
#    'per:stateorprovince_of_birth': 5,
#    'per:religion': 14,
#    'org:political/religious_affiliation': 3,
#    'per:date_of_death': 25,
#    'per:city_of_birth': 4,
#    'per:age': 1,
#    'per:city_of_death': 13,
#    'org:website': 2,
#    'per:date_of_birth': 2,
#    'per:origin': 2,
#    'org:founded_by': 1,
#    'org:founded': 1,
#    'per:cities_of_residence': 2},
#   'per:date_of_birth': {'per:city_of_birth': 5,
#    'no_relation': 15,
#    'per:date_of_birth': 4},
#   'per:spouse': {'per:spouse': 154,
#    'no_relation': 145,
#    'per:stateorprovince_of_death': 1},
#   'org:city_of_headquarters': {'no_relation': 325,
#    'org:city_of_headquarters': 48,
#    'org:political/religious_affiliation': 138,
#    'org:founded': 7,
#    'org:website': 10,
#    'org:stateorprovince_of_headquarters': 3,
#    'per:religion': 15,
#    'org:alternate_names': 2,
#    'org:parents': 2,
#    'per:cities_of_residence': 1,
#    'per:date_of_birth': 1},
#   'per:date_of_death': {'no_relation': 158,
#    'per:cause_of_death': 15,
#    'per:date_of_death': 76,
#    'per:origin': 1,
#    'org:website': 1,
#    'per:city_of_death': 13},
#   'per:schools_attended': {'no_relation': 116,
#    'per:religion': 1,
#    'per:alternate_names': 3,
#    'per:cities_of_residence': 10,
#    'per:schools_attended': 2},
#   'per:country_of_death': {'per:city_of_death': 47,
#    'per:spouse': 1,
#    'no_relation': 37,
#    'per:date_of_death': 10,
#    'org:website': 1},
#   'org:founded': {'no_relation': 16,
#    'org:member_of': 5,
#    'org:city_of_headquarters': 2,
#    'org:founded': 1},
#   'per:stateorprovince_of_birth': {'per:stateorprovince_of_birth': 10,
#    'per:stateorprovinces_of_residence': 7,
#    'per:stateorprovince_of_death': 1,
#    'per:age': 1,
#    'per:religion': 5,
#    'per:date_of_birth': 3,
#    'no_relation': 3,
#    'per:city_of_birth': 2,
#    'per:cities_of_residence': 4},
#   'per:city_of_birth': {'per:religion': 20,
#    'per:cities_of_residence': 13,
#    'per:date_of_birth': 4,
#    'per:stateorprovinces_of_residence': 3,
#    'org:founded': 1,
#    'per:city_of_birth': 3,
#    'org:political/religious_affiliation': 1,
#    'per:stateorprovince_of_birth': 1,
#    'per:origin': 2},
#   'org:dissolved': {'no_relation': 18,
#    'org:subsidiaries': 4,
#    'org:founded': 1,
#    'org:city_of_headquarters': 1}},
#  'SURE': {'no_relation': {'no_relation': 43527,
#    'per:employee_of': 19,
#    'per:siblings': 48,
#    'org:top_members/employees': 77,
#    'org:member_of': 3,
#    'per:countries_of_residence': 15,
#    'per:other_family': 13,
#    'per:country_of_death': 19,
#    'per:children': 28,
#    'per:cause_of_death': 8,
#    'org:shareholders': 13,
#    'org:founded_by': 6,
#    'per:cities_of_residence': 47,
#    'per:spouse': 30,
#    'org:alternate_names': 27,
#    'per:schools_attended': 8,
#    'org:members': 2,
#    'per:parents': 7,
#    'org:city_of_headquarters': 6,
#    'per:date_of_death': 21,
#    'per:title': 17,
#    'per:stateorprovince_of_death': 7,
#    'per:stateorprovinces_of_residence': 7,
#    'per:alternate_names': 3,
#    'org:dissolved': 8,
#    'per:city_of_death': 7,
#    'per:origin': 1,
#    'org:parents': 2,
#    'org:founded': 2,
#    'org:country_of_headquarters': 2},
#   'per:title': {'no_relation': 2341,
#    'per:employee_of': 41,
#    'per:title': 213,
#    'org:alternate_names': 28,
#    'per:other_family': 28,
#    'per:stateorprovinces_of_residence': 2,
#    'per:siblings': 3,
#    'org:top_members/employees': 8,
#    'org:member_of': 6,
#    'per:charges': 1,
#    'per:schools_attended': 2,
#    'org:city_of_headquarters': 1,
#    'per:alternate_names': 1,
#    'per:age': 1},
#   'org:top_members/employees': {'no_relation': 1774,
#    'org:top_members/employees': 745,
#    'org:founded_by': 7,
#    'org:alternate_names': 2,
#    'per:alternate_names': 1,
#    'org:parents': 3},
#   'org:country_of_headquarters': {'no_relation': 956,
#    'org:country_of_headquarters': 2,
#    'org:city_of_headquarters': 1,
#    'org:top_members/employees': 1},
#   'per:parents': {'per:parents': 213, 'no_relation': 243},
#   'per:age': {'per:age': 10, 'no_relation': 38},
#   'per:countries_of_residence': {'no_relation': 910,
#    'per:countries_of_residence': 53,
#    'per:cities_of_residence': 4,
#    'per:origin': 1,
#    'per:employee_of': 3,
#    'per:stateorprovinces_of_residence': 1},
#   'per:children': {'per:children': 40,
#    'no_relation': 66,
#    'per:parents': 8,
#    'per:spouse': 4,
#    'per:siblings': 1,
#    'per:employee_of': 1},
#   'org:alternate_names': {'no_relation': 954,
#    'org:alternate_names': 75,
#    'org:founded': 3},
#   'per:charges': {'no_relation': 129, 'per:charges': 51},
#   'per:cities_of_residence': {'no_relation': 968,
#    'per:cities_of_residence': 221,
#    'per:employee_of': 3,
#    'per:countries_of_residence': 12,
#    'per:city_of_birth': 1,
#    'per:country_of_birth': 1,
#    'per:schools_attended': 4,
#    'per:age': 1,
#    'org:city_of_headquarters': 1},
#   'per:origin': {'per:countries_of_residence': 23,
#    'no_relation': 417,
#    'per:alternate_names': 2,
#    'per:origin': 1,
#    'per:cities_of_residence': 10,
#    'per:employee_of': 1,
#    'per:stateorprovinces_of_residence': 1,
#    'org:country_of_headquarters': 1},
#   'org:founded_by': {'no_relation': 175,
#    'org:founded_by': 63,
#    'org:founded': 2},
#   'per:employee_of': {'no_relation': 1481,
#    'per:employee_of': 90,
#    'org:member_of': 2,
#    'per:cities_of_residence': 5,
#    'per:schools_attended': 3,
#    'per:title': 1,
#    'per:other_family': 1,
#    'org:founded': 1},
#   'per:siblings': {'per:siblings': 164, 'no_relation': 135, 'per:children': 1},
#   'per:alternate_names': {'no_relation': 72},
#   'per:religion': {'per:alternate_names': 7, 'no_relation': 113},
#   'per:stateorprovince_of_death': {'per:stateorprovince_of_death': 21,
#    'no_relation': 74,
#    'per:country_of_death': 8,
#    'per:city_of_death': 5},
#   'org:parents': {'no_relation': 451, 'org:shareholders': 4, 'org:parents': 1},
#   'org:subsidiaries': {'no_relation': 339, 'org:subsidiaries': 9},
#   'per:other_family': {'per:siblings': 70,
#    'no_relation': 223,
#    'per:other_family': 18,
#    'per:parents': 1},
#   'per:stateorprovinces_of_residence': {'no_relation': 420,
#    'per:stateorprovinces_of_residence': 40,
#    'per:cities_of_residence': 16,
#    'per:countries_of_residence': 13,
#    'per:schools_attended': 1,
#    'org:city_of_headquarters': 2},
#   'org:members': {'no_relation': 132},
#   'per:cause_of_death': {'per:cause_of_death': 15,
#    'no_relation': 92,
#    'per:employee_of': 1},
#   'org:member_of': {'no_relation': 120},
#   'per:country_of_birth': {'no_relation': 36},
#   'org:shareholders': {'no_relation': 107, 'org:shareholders': 1},
#   'org:stateorprovince_of_headquarters': {'no_relation': 306,
#    'org:stateorprovince_of_headquarters': 27,
#    'org:country_of_headquarters': 11,
#    'org:city_of_headquarters': 3,
#    'org:alternate_names': 1},
#   'per:city_of_death': {'no_relation': 176,
#    'per:city_of_death': 23,
#    'per:city_of_birth': 7,
#    'per:cities_of_residence': 1,
#    'per:country_of_death': 4,
#    'per:stateorprovince_of_death': 4,
#    'per:country_of_birth': 1},
#   'per:date_of_birth': {'no_relation': 23, 'per:date_of_death': 1},
#   'per:spouse': {'per:spouse': 123, 'no_relation': 177},
#   'org:city_of_headquarters': {'org:city_of_headquarters': 52,
#    'no_relation': 493,
#    'org:country_of_headquarters': 5,
#    'per:cities_of_residence': 2},
#   'per:date_of_death': {'no_relation': 187,
#    'per:date_of_death': 75,
#    'per:country_of_death': 1,
#    'per:cause_of_death': 1},
#   'per:schools_attended': {'no_relation': 86,
#    'per:schools_attended': 45,
#    'per:cities_of_residence': 1},
#   'per:country_of_death': {'no_relation': 78,
#    'per:stateorprovince_of_death': 1,
#    'per:country_of_death': 17},
#   'org:founded': {'no_relation': 24},
#   'per:stateorprovince_of_birth': {'per:stateorprovince_of_birth': 5,
#    'per:cities_of_residence': 1,
#    'per:stateorprovinces_of_residence': 10,
#    'no_relation': 19,
#    'per:country_of_birth': 1},
#   'per:city_of_birth': {'per:cities_of_residence': 6,
#    'no_relation': 34,
#    'per:city_of_birth': 5,
#    'per:country_of_birth': 2,
#    'per:schools_attended': 1},
#   'org:dissolved': {'no_relation': 24}},
#  'TYP_marker': {'no_relation': {'no_relation': 41915,
#    'org:top_members/employees': 290,
#    'org:members': 3,
#    'per:employee_of': 320,
#    'per:other_family': 59,
#    'per:title': 208,
#    'per:cities_of_residence': 176,
#    'per:children': 24,
#    'per:alternate_names': 46,
#    'per:spouse': 50,
#    'per:charges': 39,
#    'org:city_of_headquarters': 85,
#    'per:siblings': 49,
#    'org:shareholders': 45,
#    'org:alternate_names': 202,
#    'per:city_of_death': 10,
#    'per:parents': 38,
#    'org:founded_by': 5,
#    'per:cause_of_death': 10,
#    'per:religion': 17,
#    'per:countries_of_residence': 51,
#    'org:subsidiaries': 32,
#    'org:parents': 48,
#    'per:schools_attended': 15,
#    'per:origin': 10,
#    'org:country_of_headquarters': 72,
#    'org:political/religious_affiliation': 6,
#    'per:date_of_death': 30,
#    'per:stateorprovinces_of_residence': 50,
#    'org:member_of': 13,
#    'org:dissolved': 11,
#    'org:stateorprovince_of_headquarters': 35,
#    'per:stateorprovince_of_death': 8,
#    'per:city_of_birth': 2,
#    'per:date_of_birth': 2,
#    'per:age': 2,
#    'org:founded': 2},
#   'per:title': {'per:title': 1414,
#    'per:employee_of': 158,
#    'no_relation': 1024,
#    'per:origin': 9,
#    'per:alternate_names': 18,
#    'per:stateorprovinces_of_residence': 9,
#    'per:cities_of_residence': 12,
#    'per:siblings': 4,
#    'org:top_members/employees': 5,
#    'per:religion': 4,
#    'per:schools_attended': 3,
#    'per:charges': 3,
#    'per:countries_of_residence': 1,
#    'org:parents': 2,
#    'org:alternate_names': 6,
#    'org:political/religious_affiliation': 1,
#    'org:country_of_headquarters': 1,
#    'org:city_of_headquarters': 1,
#    'per:parents': 1},
#   'org:top_members/employees': {'no_relation': 721,
#    'org:top_members/employees': 1729,
#    'per:title': 22,
#    'org:founded_by': 18,
#    'org:shareholders': 1,
#    'org:political/religious_affiliation': 2,
#    'per:employee_of': 11,
#    'org:alternate_names': 6,
#    'per:origin': 4,
#    'per:age': 1,
#    'org:city_of_headquarters': 6,
#    'per:cities_of_residence': 2,
#    'org:country_of_headquarters': 3,
#    'org:subsidiaries': 3,
#    'org:website': 1,
#    'org:founded': 1,
#    'per:stateorprovinces_of_residence': 1},
#   'org:country_of_headquarters': {'no_relation': 687,
#    'org:country_of_headquarters': 210,
#    'org:city_of_headquarters': 10,
#    'org:stateorprovince_of_headquarters': 8,
#    'org:founded_by': 3,
#    'org:parents': 9,
#    'per:employee_of': 4,
#    'org:alternate_names': 12,
#    'org:subsidiaries': 2,
#    'per:countries_of_residence': 11,
#    'per:cities_of_residence': 2,
#    'org:political/religious_affiliation': 1,
#    'org:top_members/employees': 1},
#   'per:parents': {'per:parents': 272,
#    'no_relation': 141,
#    'per:other_family': 30,
#    'per:children': 7,
#    'per:religion': 2,
#    'per:country_of_birth': 1,
#    'org:parents': 2,
#    'org:top_members/employees': 1},
#   'per:age': {'per:age': 15,
#    'no_relation': 25,
#    'per:charges': 1,
#    'per:employee_of': 2,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:title': 2,
#    'per:alternate_names': 2},
#   'per:countries_of_residence': {'per:countries_of_residence': 182,
#    'no_relation': 681,
#    'per:title': 4,
#    'org:country_of_headquarters': 17,
#    'per:origin': 24,
#    'per:employee_of': 35,
#    'per:cities_of_residence': 17,
#    'per:stateorprovinces_of_residence': 7,
#    'org:city_of_headquarters': 2,
#    'per:religion': 1,
#    'per:alternate_names': 1,
#    'org:alternate_names': 1},
#   'per:children': {'per:children': 55,
#    'no_relation': 43,
#    'per:parents': 9,
#    'per:spouse': 10,
#    'per:title': 1,
#    'per:siblings': 1,
#    'org:subsidiaries': 1},
#   'org:alternate_names': {'org:alternate_names': 547,
#    'no_relation': 425,
#    'org:subsidiaries': 32,
#    'org:parents': 7,
#    'per:alternate_names': 7,
#    'org:political/religious_affiliation': 2,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:employee_of': 6,
#    'per:title': 4,
#    'org:country_of_headquarters': 1},
#   'per:charges': {'per:charges': 89, 'no_relation': 90, 'per:title': 1},
#   'per:cities_of_residence': {'per:cities_of_residence': 443,
#    'per:employee_of': 39,
#    'no_relation': 659,
#    'per:city_of_death': 6,
#    'per:origin': 4,
#    'org:city_of_headquarters': 32,
#    'per:stateorprovinces_of_residence': 7,
#    'per:countries_of_residence': 5,
#    'per:schools_attended': 6,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:parents': 1,
#    'per:religion': 4,
#    'org:parents': 2,
#    'org:country_of_headquarters': 1,
#    'per:alternate_names': 2},
#   'per:origin': {'per:origin': 60,
#    'no_relation': 268,
#    'per:countries_of_residence': 65,
#    'per:employee_of': 26,
#    'per:cities_of_residence': 10,
#    'per:stateorprovinces_of_residence': 4,
#    'org:country_of_headquarters': 14,
#    'per:title': 3,
#    'per:charges': 1,
#    'org:member_of': 1,
#    'org:political/religious_affiliation': 1,
#    'per:alternate_names': 3},
#   'org:founded_by': {'no_relation': 108,
#    'org:founded_by': 109,
#    'org:top_members/employees': 10,
#    'org:country_of_headquarters': 1,
#    'per:siblings': 4,
#    'org:founded': 5,
#    'per:spouse': 1,
#    'org:parents': 1,
#    'per:cause_of_death': 1},
#   'per:employee_of': {'per:employee_of': 708,
#    'no_relation': 769,
#    'per:cities_of_residence': 48,
#    'per:schools_attended': 4,
#    'per:origin': 1,
#    'org:top_members/employees': 5,
#    'per:countries_of_residence': 8,
#    'per:stateorprovinces_of_residence': 3,
#    'per:title': 14,
#    'per:cause_of_death': 1,
#    'org:member_of': 1,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:religion': 3,
#    'org:parents': 8,
#    'org:city_of_headquarters': 3,
#    'org:subsidiaries': 2,
#    'org:alternate_names': 4,
#    'per:charges': 1},
#   'per:siblings': {'per:siblings': 176,
#    'no_relation': 122,
#    'per:title': 1,
#    'per:employee_of': 1},
#   'per:alternate_names': {'no_relation': 68,
#    'per:alternate_names': 3,
#    'org:alternate_names': 1},
#   'per:religion': {'per:religion': 18,
#    'no_relation': 93,
#    'per:employee_of': 3,
#    'org:political/religious_affiliation': 4,
#    'per:title': 1,
#    'org:city_of_headquarters': 1},
#   'per:stateorprovince_of_death': {'per:stateorprovince_of_death': 26,
#    'no_relation': 73,
#    'per:stateorprovinces_of_residence': 6,
#    'per:city_of_death': 1,
#    'per:cities_of_residence': 1,
#    'per:religion': 1},
#   'org:parents': {'org:parents': 171,
#    'no_relation': 254,
#    'org:country_of_headquarters': 6,
#    'org:city_of_headquarters': 1,
#    'org:shareholders': 6,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:employee_of': 11,
#    'org:subsidiaries': 5,
#    'org:political/religious_affiliation': 1},
#   'org:subsidiaries': {'org:subsidiaries': 89,
#    'no_relation': 236,
#    'org:parents': 14,
#    'org:stateorprovince_of_headquarters': 2,
#    'per:employee_of': 1,
#    'org:top_members/employees': 2,
#    'per:title': 1,
#    'org:alternate_names': 3},
#   'per:other_family': {'per:other_family': 181,
#    'no_relation': 128,
#    'per:origin': 2,
#    'per:children': 1},
#   'per:stateorprovinces_of_residence': {'no_relation': 288,
#    'org:country_of_headquarters': 1,
#    'per:stateorprovinces_of_residence': 117,
#    'per:cities_of_residence': 34,
#    'org:city_of_headquarters': 2,
#    'org:stateorprovince_of_headquarters': 13,
#    'per:employee_of': 9,
#    'per:stateorprovince_of_death': 1,
#    'per:city_of_death': 12,
#    'per:schools_attended': 5,
#    'per:stateorprovince_of_birth': 4,
#    'org:alternate_names': 1,
#    'per:title': 4,
#    'org:top_members/employees': 1},
#   'org:members': {'no_relation': 113,
#    'org:members': 5,
#    'org:subsidiaries': 3,
#    'org:country_of_headquarters': 4,
#    'per:employee_of': 2,
#    'org:top_members/employees': 2,
#    'per:charges': 1,
#    'org:alternate_names': 2},
#   'per:cause_of_death': {'per:cause_of_death': 45,
#    'no_relation': 61,
#    'per:employee_of': 1,
#    'per:charges': 1},
#   'org:member_of': {'org:parents': 24,
#    'no_relation': 76,
#    'org:top_members/employees': 1,
#    'org:member_of': 5,
#    'org:stateorprovince_of_headquarters': 1,
#    'org:country_of_headquarters': 10,
#    'org:subsidiaries': 1,
#    'per:countries_of_residence': 1,
#    'org:alternate_names': 1},
#   'per:country_of_birth': {'per:countries_of_residence': 12,
#    'no_relation': 18,
#    'per:stateorprovinces_of_residence': 5,
#    'per:cities_of_residence': 1},
#   'org:shareholders': {'no_relation': 79,
#    'org:parents': 19,
#    'org:founded_by': 6,
#    'org:top_members/employees': 1,
#    'org:country_of_headquarters': 3},
#   'org:stateorprovince_of_headquarters': {'no_relation': 193,
#    'org:parents': 6,
#    'org:stateorprovince_of_headquarters': 105,
#    'org:city_of_headquarters': 18,
#    'per:stateorprovinces_of_residence': 12,
#    'org:top_members/employees': 3,
#    'per:title': 1,
#    'org:subsidiaries': 1,
#    'per:employee_of': 2,
#    'org:founded_by': 1,
#    'per:cities_of_residence': 1,
#    'org:alternate_names': 3,
#    'org:country_of_headquarters': 1,
#    'org:founded': 1},
#   'per:city_of_death': {'no_relation': 146,
#    'per:city_of_death': 42,
#    'per:city_of_birth': 11,
#    'per:cities_of_residence': 6,
#    'org:city_of_headquarters': 4,
#    'per:stateorprovince_of_death': 6,
#    'per:employee_of': 1},
#   'per:date_of_birth': {'per:date_of_birth': 8,
#    'no_relation': 15,
#    'per:parents': 1},
#   'per:spouse': {'per:spouse': 191,
#    'no_relation': 108,
#    'per:cities_of_residence': 1},
#   'org:city_of_headquarters': {'org:city_of_headquarters': 187,
#    'no_relation': 315,
#    'org:country_of_headquarters': 7,
#    'org:parents': 4,
#    'org:stateorprovince_of_headquarters': 8,
#    'per:employee_of': 3,
#    'org:subsidiaries': 5,
#    'per:cities_of_residence': 15,
#    'org:founded': 1,
#    'per:title': 1,
#    'org:top_members/employees': 1,
#    'org:number_of_employees/members': 2,
#    'org:alternate_names': 3},
#   'per:date_of_death': {'no_relation': 183,
#    'per:date_of_death': 78,
#    'per:city_of_death': 1,
#    'per:employee_of': 1,
#    'per:origin': 1},
#   'per:schools_attended': {'no_relation': 75,
#    'per:schools_attended': 50,
#    'per:cities_of_residence': 2,
#    'per:employee_of': 4,
#    'per:title': 1},
#   'per:country_of_death': {'no_relation': 77,
#    'per:stateorprovince_of_death': 1,
#    'per:countries_of_residence': 15,
#    'per:stateorprovinces_of_residence': 1,
#    'per:employee_of': 1,
#    'org:country_of_headquarters': 1},
#   'org:founded': {'org:founded': 10, 'no_relation': 14},
#   'per:stateorprovince_of_birth': {'per:stateorprovince_of_birth': 8,
#    'per:stateorprovinces_of_residence': 14,
#    'no_relation': 8,
#    'per:employee_of': 1,
#    'org:stateorprovince_of_headquarters': 2,
#    'per:alternate_names': 3},
#   'per:city_of_birth': {'per:cities_of_residence': 29,
#    'per:city_of_birth': 10,
#    'per:stateorprovinces_of_residence': 1,
#    'no_relation': 6,
#    'org:city_of_headquarters': 1,
#    'per:stateorprovince_of_birth': 1},
#   'org:dissolved': {'no_relation': 15, 'org:dissolved': 9}},
#  'UniST': {'no_relation': {'no_relation': 41928,
#    'per:religion': 17,
#    'org:top_members/employees': 313,
#    'per:cities_of_residence': 126,
#    'per:title': 220,
#    'per:employee_of': 458,
#    'per:children': 32,
#    'per:other_family': 50,
#    'org:parents': 43,
#    'per:alternate_names': 30,
#    'per:countries_of_residence': 39,
#    'org:alternate_names': 216,
#    'per:siblings': 52,
#    'org:city_of_headquarters': 61,
#    'org:shareholders': 16,
#    'org:founded_by': 19,
#    'per:charges': 16,
#    'per:schools_attended': 20,
#    'org:subsidiaries': 40,
#    'per:cause_of_death': 15,
#    'per:spouse': 34,
#    'per:country_of_death': 1,
#    'org:website': 3,
#    'per:parents': 22,
#    'org:country_of_headquarters': 71,
#    'per:origin': 9,
#    'per:stateorprovinces_of_residence': 31,
#    'org:members': 2,
#    'per:city_of_death': 13,
#    'org:member_of': 8,
#    'per:date_of_death': 12,
#    'org:stateorprovince_of_headquarters': 31,
#    'org:dissolved': 5,
#    'per:date_of_birth': 1,
#    'per:country_of_birth': 2,
#    'per:stateorprovinces_of_death': 7,
#    'per:age': 2,
#    'org:political/religious affiliation': 8,
#    'org:founded': 1,
#    'per:city_of_birth': 6},
#   'per:title': {'per:title': 1359,
#    'per:employee_of': 197,
#    'no_relation': 1044,
#    'per:origin': 9,
#    'per:alternate_names': 12,
#    'per:stateorprovinces_of_residence': 10,
#    'per:cities_of_residence': 8,
#    'per:siblings': 3,
#    'per:countries_of_residence': 3,
#    'org:top_members/employees': 11,
#    'per:religion': 4,
#    'per:schools_attended': 2,
#    'per:charges': 2,
#    'per:age': 1,
#    'per:parents': 1,
#    'org:alternate_names': 5,
#    'org:city_of_headquarters': 1,
#    'org:founded_by': 1,
#    'org:political/religious affiliation': 1,
#    'org:member_of': 1,
#    'org:stateorprovince_of_headquarters': 1},
#   'org:top_members/employees': {'no_relation': 1032,
#    'org:top_members/employees': 1401,
#    'org:founded_by': 15,
#    'per:title': 25,
#    'org:country_of_headquarters': 4,
#    'per:employee_of': 26,
#    'per:origin': 1,
#    'per:age': 1,
#    'org:alternate_names': 19,
#    'org:members': 1,
#    'org:subsidiaries': 4,
#    'org:shareholders': 1,
#    'per:religion': 1,
#    'org:stateorprovince_of_headquarters': 1},
#   'org:country_of_headquarters': {'no_relation': 746,
#    'org:parents': 6,
#    'org:country_of_headquarters': 163,
#    'org:city_of_headquarters': 14,
#    'org:alternate_names': 9,
#    'per:countries_of_residence': 3,
#    'org:subsidiaries': 3,
#    'org:top_members/employees': 6,
#    'per:origin': 1,
#    'per:employee_of': 5,
#    'org:political/religious affiliation': 1,
#    'org:member_of': 2,
#    'per:title': 1},
#   'per:parents': {'per:parents': 216,
#    'no_relation': 201,
#    'per:children': 3,
#    'per:siblings': 2,
#    'per:other_family': 20,
#    'per:employee_of': 3,
#    'org:top_members/employees': 3,
#    'per:title': 1,
#    'per:religion': 1,
#    'org:parents': 1,
#    'org:founded_by': 5},
#   'per:age': {'per:age': 10,
#    'per:date_of_birth': 1,
#    'no_relation': 30,
#    'per:charges': 1,
#    'per:employee_of': 3,
#    'per:alternate_names': 3},
#   'per:countries_of_residence': {'no_relation': 706,
#    'per:countries_of_residence': 175,
#    'per:country_of_birth': 9,
#    'per:origin': 6,
#    'org:country_of_headquarters': 19,
#    'per:employee_of': 32,
#    'per:cities_of_residence': 11,
#    'per:stateorprovinces_of_residence': 5,
#    'per:title': 2,
#    'per:schools_attended': 2,
#    'per:alternate_names': 2,
#    'org:city_of_headquarters': 1,
#    'org:alternate_names': 1,
#    'per:religion': 1},
#   'per:children': {'per:children': 44,
#    'no_relation': 58,
#    'per:parents': 9,
#    'per:spouse': 5,
#    'per:cities_of_residence': 1,
#    'per:siblings': 1,
#    'per:employee_of': 1,
#    'per:title': 1},
#   'org:alternate_names': {'org:alternate_names': 504,
#    'no_relation': 498,
#    'org:country_of_headquarters': 2,
#    'org:subsidiaries': 2,
#    'per:title': 4,
#    'org:parents': 1,
#    'org:political/religious affiliation': 2,
#    'org:stateorprovince_of_headquarters': 1,
#    'per:employee_of': 6,
#    'per:alternate_names': 3,
#    'org:member_of': 1,
#    'org:top_members/employees': 7,
#    'per:age': 1},
#   'per:charges': {'no_relation': 95,
#    'per:charges': 76,
#    'per:employee_of': 8,
#    'per:alternate_names': 1},
#   'per:cities_of_residence': {'no_relation': 705,
#    'per:employee_of': 54,
#    'per:cities_of_residence': 392,
#    'per:city_of_death': 3,
#    'per:origin': 3,
#    'org:city_of_headquarters': 35,
#    'per:stateorprovinces_of_residence': 4,
#    'per:title': 1,
#    'per:countries_of_residence': 2,
#    'per:schools_attended': 3,
#    'org:stateorprovince_of_headquarters': 1,
#    'org:top_members/employees': 2,
#    'per:charges': 1,
#    'per:religion': 3,
#    'per:age': 1,
#    'org:parents': 1,
#    'per:city_of_birth': 1},
#   'per:origin': {'per:origin': 49,
#    'per:countries_of_residence': 68,
#    'no_relation': 273,
#    'per:employee_of': 30,
#    'per:cities_of_residence': 9,
#    'per:stateorprovinces_of_residence': 4,
#    'org:country_of_headquarters': 11,
#    'per:country_of_birth': 3,
#    'per:date_of_birth': 2,
#    'per:charges': 2,
#    'per:title': 2,
#    'org:political/religious affiliation': 1,
#    'per:alternate_names': 2},
#   'org:founded_by': {'no_relation': 111,
#    'org:founded_by': 114,
#    'org:top_members/employees': 9,
#    'org:country_of_headquarters': 1,
#    'org:founded': 1,
#    'per:alternate_names': 1,
#    'per:spouse': 1,
#    'per:title': 2},
#   'per:employee_of': {'per:employee_of': 636,
#    'no_relation': 860,
#    'per:cities_of_residence': 33,
#    'per:origin': 2,
#    'per:countries_of_residence': 5,
#    'per:stateorprovinces_of_residence': 4,
#    'per:title': 12,
#    'org:top_members/employees': 12,
#    'org:member_of': 2,
#    'per:religion': 3,
#    'per:alternate_names': 2,
#    'per:charges': 1,
#    'org:alternate_names': 4,
#    'org:city_of_headquarters': 2,
#    'org:parents': 6},
#   'per:siblings': {'per:siblings': 132,
#    'per:children': 5,
#    'no_relation': 153,
#    'per:parents': 1,
#    'per:cities_of_residence': 1,
#    'per:employee_of': 4,
#    'per:title': 3,
#    'org:founded_by': 1},
#   'per:alternate_names': {'no_relation': 71, 'per:employee_of': 1},
#   'per:religion': {'per:religion': 20,
#    'no_relation': 86,
#    'org:political/religious affiliation': 8,
#    'per:employee_of': 2,
#    'per:title': 1,
#    'org:city_of_headquarters': 1,
#    'per:alternate_names': 2},
#   'per:stateorprovince_of_death': {'NA': 108},
#   'org:parents': {'NA': 456},
#   'org:subsidiaries': {'NA': 348},
#   'per:other_family': {'NA': 312},
#   'per:stateorprovinces_of_residence': {'NA': 492},
#   'org:members': {'NA': 132},
#   'per:cause_of_death': {'NA': 108},
#   'org:member_of': {'NA': 120},
#   'per:country_of_birth': {'NA': 36},
#   'org:shareholders': {'NA': 108},
#   'org:stateorprovince_of_headquarters': {'NA': 348},
#   'per:city_of_death': {'NA': 216},
#   'per:date_of_birth': {'NA': 24},
#   'per:spouse': {'NA': 300},
#   'org:city_of_headquarters': {'NA': 552},
#   'per:date_of_death': {'NA': 264},
#   'per:schools_attended': {'NA': 132},
#   'per:country_of_death': {'NA': 96},
#   'org:founded': {'NA': 24},
#   'per:stateorprovince_of_birth': {'NA': 36},
#   'per:city_of_birth': {'NA': 48},
#   'org:dissolved': {'NA': 24}},
#  'NLI_w': {'no_relation': {'no_relation': 43112,
#    'per:cities_of_residence': 84,
#    'per:employee_of': 195,
#    'org:top_members/employees': 92,
#    'org:members': 15,
#    'per:other_family': 40,
#    'per:children': 18,
#    'per:countries_of_residence': 30,
#    'per:alternate_names': 24,
#    'org:city_of_headquarters': 58,
#    'org:founded_by': 13,
#    'per:title': 72,
#    'per:charges': 11,
#    'org:country_of_headquarters': 60,
#    'per:country_of_death': 7,
#    'per:parents': 13,
#    'org:member_of': 20,
#    'org:shareholders': 2,
#    'org:alternate_names': 18,
#    'org:parents': 16,
#    'per:cause_of_death': 3,
#    'per:schools_attended': 8,
#    'org:subsidiaries': 5,
#    'per:spouse': 17,
#    'per:date_of_death': 9,
#    'org:dissolved': 5,
#    'per:stateorprovinces_of_residence': 15,
#    'per:siblings': 3,
#    'per:city_of_death': 3,
#    'org:stateorprovince_of_headquarters': 5,
#    'org:political/religious_affiliation': 4,
#    'per:religion': 1,
#    'per:origin': 2},
#   'per:title': {'per:title': 903,
#    'no_relation': 1595,
#    'org:alternate_names': 6,
#    'per:employee_of': 122,
#    'per:alternate_names': 22,
#    'per:origin': 6,
#    'per:stateorprovinces_of_residence': 2,
#    'per:other_family': 1,
#    'per:siblings': 1,
#    'per:schools_attended': 3,
#    'per:religion': 3,
#    'per:cities_of_residence': 1,
#    'per:charges': 1,
#    'org:member_of': 8,
#    'org:founded': 1,
#    'org:members': 1},
#   'org:top_members/employees': {'no_relation': 1620,
#    'org:top_members/employees': 843,
#    'org:members': 47,
#    'org:founded_by': 9,
#    'org:political/religious_affiliation': 1,
#    'per:alternate_names': 2,
#    'org:alternate_names': 1,
#    'org:country_of_headquarters': 6,
#    'org:number_of_employees/members': 2,
#    'per:employee_of': 1},
#   'org:country_of_headquarters': {'no_relation': 838,
#    'org:country_of_headquarters': 109,
#    'org:city_of_headquarters': 9,
#    'per:countries_of_residence': 3,
#    'org:member_of': 1},
#   'per:parents': {'per:parents': 158,
#    'no_relation': 286,
#    'per:other_family': 4,
#    'per:alternate_names': 1,
#    'per:children': 4,
#    'per:employee_of': 1,
#    'per:religion': 1,
#    'org:parents': 1},
#   'per:age': {'no_relation': 40,
#    'per:age': 2,
#    'per:alternate_names': 1,
#    'per:charges': 1,
#    'per:employee_of': 2,
#    'org:city_of_headquarters': 1,
#    'org:member_of': 1},
#   'per:countries_of_residence': {'per:countries_of_residence': 134,
#    'no_relation': 778,
#    'per:employee_of': 19,
#    'per:origin': 16,
#    'per:cities_of_residence': 6,
#    'org:member_of': 5,
# ...
#    'org:member_of': 1,
#    'per:stateorprovince_of_birth': 1,
#    'per:country_of_birth': 1,
#    'org:country_of_headquarters': 6,
#    'per:charges': 2,
#    'per:title': 2,
#    'org:political/religious_affiliation': 1},
#   'org:founded_by': {'no_relation': 180,
#    'org:founded_by': 59,
#    'org:country_of_headquarters': 1},
#   'per:employee_of': {'per:employee_of': 479,
#    'no_relation': 1026,
#    'per:origin': 4,
#    'per:cities_of_residence': 17,
#    'per:alternate_names': 2,
#    'per:stateorprovinces_of_residence': 2,
#    'per:title': 5,
#    'org:member_of': 41,
#    'org:top_members/employees': 3,
#    'per:religion': 1,
#    'per:other_family': 1,
#    'org:members': 1,
#    'org:alternate_names': 2},
#   'per:siblings': {'per:siblings': 76,
#    'per:children': 3,
#    'no_relation': 217,
#    'per:parents': 2,
#    'per:alternate_names': 1,
#    'per:title': 1},
#   'per:alternate_names': {'no_relation': 71, 'org:alternate_names': 1},
#   'per:religion': {'per:religion': 12,
#    'no_relation': 100,
#    'org:political/religious_affiliation': 4,
#    'per:employee_of': 1,
#    'per:title': 1,
#    'org:member_of': 1,
#    'org:city_of_headquarters': 1},
#   'per:stateorprovince_of_death': {'no_relation': 102,
#    'per:city_of_death': 1,
#    'per:stateorprovinces_of_residence': 1,
#    'per:stateorprovince_of_death': 4},
#   'org:parents': {'no_relation': 415,
#    'org:city_of_headquarters': 1,
#    'org:parents': 27,
#    'org:shareholders': 1,
#    'org:country_of_headquarters': 3,
#    'org:subsidiaries': 2,
#    'org:alternate_names': 2,
#    'per:employee_of': 5},
#   'org:subsidiaries': {'no_relation': 312,
#    'org:parents': 4,
#    'org:subsidiaries': 28,
#    'org:city_of_headquarters': 1,
#    'org:stateorprovince_of_headquarters': 1,
#    'org:member_of': 1,
#    'org:alternate_names': 1},
#   'per:other_family': {'per:other_family': 81,
#    'no_relation': 225,
#    'per:parents': 4,
#    'per:siblings': 2},
#   'per:stateorprovinces_of_residence': {'no_relation': 375,
#    'per:stateorprovinces_of_residence': 67,
#    'per:cities_of_residence': 13,
#    'per:employee_of': 9,
#    'per:schools_attended': 2,
#    'org:stateorprovince_of_headquarters': 9,
#    'per:countries_of_residence': 8,
#    'org:member_of': 4,
#    'per:siblings': 1,
#    'per:stateorprovince_of_birth': 1,
#    'org:city_of_headquarters': 2,
#    'org:alternate_names': 1},
#   'org:members': {'no_relation': 121,
#    'org:members': 7,
#    'org:alternate_names': 2,
#    'org:country_of_headquarters': 1,
#    'org:top_members/employees': 1},
#   'per:cause_of_death': {'per:cause_of_death': 27, 'no_relation': 81},
#   'org:member_of': {'org:member_of': 11,
#    'no_relation': 104,
#    'org:parents': 2,
#    'org:country_of_headquarters': 3},
#   'per:country_of_birth': {'per:countries_of_residence': 6,
#    'no_relation': 25,
#    'per:country_of_birth': 2,
#    'per:stateorprovinces_of_residence': 1,
#    'per:stateorprovince_of_birth': 1,
#    'org:country_of_headquarters': 1},
#   'org:shareholders': {'no_relation': 96,
#    'org:parents': 9,
#    'org:member_of': 1,
#    'org:country_of_headquarters': 2},
#   'org:stateorprovince_of_headquarters': {'no_relation': 265,
#    'org:stateorprovince_of_headquarters': 66,
#    'org:country_of_headquarters': 6,
#    'org:city_of_headquarters': 8,
#    'per:stateorprovinces_of_residence': 1,
#    'per:employee_of': 1,
#    'per:cities_of_residence': 1},
#   'per:city_of_death': {'per:city_of_death': 30,
#    'no_relation': 177,
#    'per:city_of_birth': 4,
#    'per:cities_of_residence': 3,
#    'per:stateorprovince_of_death': 1,
#    'per:charges': 1},
#   'per:date_of_birth': {'per:date_of_birth': 6, 'no_relation': 18},
#   'per:spouse': {'per:spouse': 104,
#    'no_relation': 194,
#    'org:member_of': 1,
#    'per:employee_of': 1},
#   'org:city_of_headquarters': {'org:city_of_headquarters': 124,
#    'no_relation': 410,
#    'org:stateorprovince_of_headquarters': 2,
#    'org:country_of_headquarters': 6,
#    'org:founded': 1,
#    'per:cities_of_residence': 9},
#   'per:date_of_death': {'no_relation': 195, 'per:date_of_death': 69},
#   'per:schools_attended': {'no_relation': 98,
#    'per:schools_attended': 33,
#    'per:cities_of_residence': 1},
#   'per:country_of_death': {'per:country_of_death': 24, 'no_relation': 72},
#   'org:founded': {'no_relation': 23, 'org:founded': 1},
#   'per:stateorprovince_of_birth': {'per:stateorprovince_of_birth': 7,
#    'no_relation': 25,
#    'per:stateorprovinces_of_residence': 4},
#   'per:city_of_birth': {'no_relation': 33,
#    'per:stateorprovinces_of_residence': 1,
#    'per:city_of_birth': 3,
#    'per:cities_of_residence': 8,
#    'org:city_of_headquarters': 1,
#    'per:stateorprovince_of_birth': 1,
#    'per:employee_of': 1},
#   'org:dissolved': {'no_relation': 20, 'org:dissolved': 4}},
#  'NLI_wo': {'no_relation': {'no_relation': 41929,
#    'org:political/religious_affiliation': 53,
#    'per:cities_of_residence': 116,
#    'per:other_family': 25,
#    'per:employee_of': 207,
#    'org:city_of_headquarters': 133,
#    'org:member_of': 64,
#    'org:members': 125,
#    'per:charges': 130,
#    'per:title': 151,
#    'org:top_members/employees': 146,
#    'per:spouse': 72,
#    'per:children': 23,
#    'per:parents': 25,
#    'per:cause_of_death': 62,
#    'org:website': 41,
#    'org:founded_by': 17,
#    'org:parents': 10,
#    'org:alternate_names': 117,
#    'per:alternate_names': 214,
#    'org:country_of_headquarters': 107,
#    'per:country_of_death': 15,
#    'org:shareholders': 3,
#    'org:founded': 10,
#    'org:subsidiaries': 28,
#    'per:city_of_death': 25,
#    'per:siblings': 18,
#    'per:stateorprovinces_of_residence': 13,
#    'per:countries_of_residence': 34,
#    'per:date_of_death': 18,
#    'org:dissolved': 6,
#    'org:stateorprovince_of_headquarters': 3,
#    'per:origin': 6,
#    'per:stateorprovince_of_death': 4,
#    'per:schools_attended': 10,
#    'per:age': 18,
#    'per:religion': 2},
#   'per:title': {'per:title': 995,
#    'per:employee_of': 91,
#    'no_relation': 1205,
#    'org:member_of': 93,
#    'per:siblings': 4,
#    'org:alternate_names': 67,
#    'per:alternate_names': 151,
#    'org:political/religious_affiliation': 6,
#    'per:cities_of_residence': 3,
#    'org:members': 16,
#    'org:top_members/employees': 7,
#    'per:other_family': 3,
#    'per:charges': 19,
#    'org:founded_by': 2,
#    'per:age': 6,
#    'per:schools_attended': 3,
#    'per:religion': 2,
#    'org:country_of_headquarters': 1,
#    'org:founded': 1,
#    'per:origin': 1},
#   'org:top_members/employees': {'org:members': 227,
#    'no_relation': 1192,
#    'org:political/religious_affiliation': 15,
#    'org:top_members/employees': 970,
#    'org:country_of_headquarters': 4,
#    'org:founded_by': 16,
#    'per:title': 8,
#    'per:alternate_names': 56,
#    'per:charges': 1,
#    'per:employee_of': 7,
#    'org:member_of': 9,
#    'org:website': 4,
#    'org:alternate_names': 20,
#    'org:city_of_headquarters': 1,
#    'per:countries_of_residence': 1,
#    'per:origin': 1},
#   'org:country_of_headquarters': {'no_relation': 773,
#    'org:country_of_headquarters': 130,
#    'org:city_of_headquarters': 19,
#    'org:political/religious_affiliation': 10,
#    'per:title': 1,
#    'org:website': 8,
#    'per:countries_of_residence': 3,
#    'per:employee_of': 1,
#    'per:charges': 1,
#    'per:alternate_names': 6,
#    'org:stateorprovince_of_headquarters': 1,
#    'org:alternate_names': 7},
#   'per:parents': {'no_relation': 330,
#    'per:parents': 95,
#    'per:siblings': 1,
#    'per:children': 15,
#    'per:title': 2,
#    'per:other_family': 2,
#    'per:employee_of': 2,
#    'org:members': 2,
#    'per:religion': 1,
#    'per:alternate_names': 3,
#    'org:alternate_names': 3},
#   'per:age': {'no_relation': 27,
#    'per:age': 2,
#    'per:alternate_names': 4,
#    'per:title': 9,
#    'per:employee_of': 2,
#    'org:alternate_names': 2,
#    'org:city_of_headquarters': 1,
#    'per:cities_of_residence': 1},
#   'per:countries_of_residence': {'per:employee_of': 57,
#    'no_relation': 666,
#    'org:political/religious_affiliation': 15,
#    'per:countries_of_residence': 94,
#    'per:origin': 6,
#    'per:title': 14,
#    'org:country_of_headquarters': 12,
#    'per:schools_attended': 7,
#    'org:member_of': 17,
#    'per:cities_of_residence': 25,
#    'per:charges': 29,
#    'per:stateorprovinces_of_residence': 4,
#    'org:top_members/employees': 1,
#    'org:city_of_headquarters': 2,
#    'per:alternate_names': 15,
#    'org:alternate_names': 4,
#    'org:website': 1,
#    'per:age': 1,
#    'per:parents': 1,
#    'org:members': 1},
#   'per:children': {'no_relation': 86,
#    'per:spouse': 4,
#    'per:children': 25,
#    'per:employee_of': 1,
#    'per:parents': 3,
#    'org:alternate_names': 1},
#   'org:alternate_names': {'no_relation': 969,
#    'org:alternate_names': 34,
#    'per:alternate_names': 23,
#    'per:parents': 1,
#    'per:title': 3,
#    'org:website': 2},
#   'per:charges': {'per:charges': 80,
#    'no_relation': 95,
#    'per:cause_of_death': 2,
#    'per:title': 1,
#    'per:employee_of': 1,
#    'per:alternate_names': 1},
#   'per:cities_of_residence': {'per:cities_of_residence': 311,
#    'per:employee_of': 115,
#    'no_relation': 615,
#    'org:city_of_headquarters': 70,
#    'org:country_of_headquarters': 6,
#    'per:schools_attended': 7,
#    'per:countries_of_residence': 12,
#    'org:political/religious_affiliation': 9,
#    'org:top_members/employees': 6,
#    'org:member_of': 11,
#    'per:title': 4,
#    'per:city_of_birth': 1,
#    'per:charges': 2,
#    'per:age': 3,
#    'per:city_of_death': 1,
#    'per:alternate_names': 27,
#    'org:alternate_names': 10,
#    'per:stateorprovinces_of_residence': 1,
#    'per:other_family': 1},
#   'per:origin': {'per:title': 49,
#    'no_relation': 253,
#    'per:origin': 13,
#    'per:countries_of_residence': 44,
#    'per:employee_of': 36,
#    'org:member_of': 13,
#    'per:cities_of_residence': 5,
#    'per:alternate_names': 12,
#    'org:political/religious_affiliation': 8,
#    'org:country_of_headquarters': 9,
#    'per:charges': 8,
#    'per:stateorprovince_of_birth': 1,
#    'per:country_of_birth': 1,
#    'per:age': 2,
#    'org:city_of_headquarters': 1,
#    'org:alternate_names': 1},
#   'org:founded_by': {'no_relation': 141,
#    'org:founded_by': 94,
#    'org:members': 3,
#    'org:alternate_names': 1,
#    'per:spouse': 1},
#   'per:employee_of': {'org:top_members/employees': 148,
#    'per:employee_of': 346,
#    'no_relation': 895,
#    'org:member_of': 95,
#    'org:members': 12,
#    'per:title': 18,
#    'org:alternate_names': 9,
#    'per:cities_of_residence': 11,
#    'org:political/religious_affiliation': 5,
#    'per:charges': 1,
#    'per:origin': 2,
#    'org:city_of_headquarters': 4,
#    'per:alternate_names': 32,
#    'org:website': 2,
#    'org:founded_by': 1,
#    'per:age': 3},
#   'per:siblings': {'no_relation': 244,
#    'per:siblings': 48,
#    'per:parents': 1,
#    'per:title': 2,
#    'org:alternate_names': 2,
#    'per:other_family': 2,
#    'per:alternate_names': 1},
#   'per:alternate_names': {'no_relation': 67,
#    'org:alternate_names': 3,
#    'per:origin': 1,
#    'per:title': 1},
#   'per:religion': {'per:religion': 9,
#    'no_relation': 88,
#    'per:employee_of': 2,
#    'per:title': 10,
#    'org:political/religious_affiliation': 6,
#    'org:member_of': 2,
#    'per:alternate_names': 2,
#    'org:top_members/employees': 1},
#   'per:stateorprovince_of_death': {'per:city_of_death': 14,
#    'per:country_of_death': 16,
#    'no_relation': 70,
#    'per:cities_of_residence': 1,
#    'per:date_of_death': 1,
#    'per:cause_of_death': 3,
#    'per:stateorprovince_of_death': 2,
#    'per:age': 1},
#   'org:parents': {'no_relation': 419,
#    'org:city_of_headquarters': 1,
#    'org:political/religious_affiliation': 2,
#    'per:title': 2,
#    'org:parents': 13,
#    'org:country_of_headquarters': 2,
#    'org:shareholders': 2,
#    'per:employee_of': 4,
#    'org:subsidiaries': 1,
#    'per:alternate_names': 6,
#    'org:website': 1,
#    'org:alternate_names': 3},
#   'org:subsidiaries': {'no_relation': 326,
#    'org:city_of_headquarters': 2,
#    'org:alternate_names': 1,
#    'org:parents': 2,
#    'org:subsidiaries': 8,
#    'per:children': 4,
#    'per:employee_of': 1,
#    'per:alternate_names': 3,
#    'org:website': 1},
#   'per:other_family': {'no_relation': 268,
#    'per:other_family': 35,
#    'per:siblings': 2,
#    'per:parents': 1,
#    'org:political/religious_affiliation': 1,
#    'per:title': 1,
#    'per:alternate_names': 2,
#    'org:alternate_names': 1,
#    'per:charges': 1},
#   'per:stateorprovinces_of_residence': {'no_relation': 296,
#    'org:city_of_headquarters': 13,
#    'per:country_of_birth': 2,
#    'per:schools_attended': 14,
#    'org:country_of_headquarters': 23,
#    'org:stateorprovince_of_headquarters': 3,
#    'per:stateorprovinces_of_residence': 19,
#    'per:employee_of': 25,
#    'per:cities_of_residence': 28,
#    'per:title': 8,
#    'per:countries_of_residence': 31,
#    'org:political/religious_affiliation': 3,
#    'org:member_of': 3,
#    'per:charges': 8,
#    'per:alternate_names': 11,
#    'org:members': 1,
#    'per:city_of_death': 1,
#    'org:alternate_names': 2,
#    'per:age': 1},
#   'org:members': {'no_relation': 122,
#    'org:members': 5,
#    'org:country_of_headquarters': 1,
#    'org:top_members/employees': 1,
#    'org:website': 2,
#    'per:alternate_names': 1},
#   'per:cause_of_death': {'per:cause_of_death': 48,
#    'no_relation': 57,
#    'per:alternate_names': 1,
#    'per:age': 2},
#   'org:member_of': {'no_relation': 105,
#    'org:political/religious_affiliation': 3,
#    'org:country_of_headquarters': 5,
#    'org:member_of': 3,
#    'org:parents': 1,
#    'per:employee_of': 1,
#    'per:alternate_names': 1,
#    'org:alternate_names': 1},
#   'per:country_of_birth': {'per:countries_of_residence': 8,
#    'no_relation': 21,
#    'org:political/religious_affiliation': 1,
#    'per:stateorprovinces_of_residence': 1,
#    'per:stateorprovince_of_birth': 1,
#    'per:country_of_birth': 1,
#    'org:alternate_names': 1,
#    'per:alternate_names': 2},
#   'org:shareholders': {'no_relation': 96,
#    'per:title': 4,
#    'org:country_of_headquarters': 3,
#    'org:political/religious_affiliation': 1,
#    'org:parents': 2,
#    'org:website': 1,
#    'org:alternate_names': 1},
#   'org:stateorprovince_of_headquarters': {'no_relation': 201,
#    'org:country_of_headquarters': 57,
#    'org:stateorprovince_of_headquarters': 5,
#    'org:founded': 12,
#    'org:political/religious_affiliation': 4,
#    'org:city_of_headquarters': 55,
#    'per:cities_of_residence': 1,
#    'per:title': 3,
#    'per:employee_of': 1,
#    'org:website': 6,
#    'per:alternate_names': 3},
#   'per:city_of_death': {'per:city_of_death': 54,
#    'no_relation': 145,
#    'per:city_of_birth': 5,
#    'per:cities_of_residence': 4,
#    'per:date_of_birth': 2,
#    'per:date_of_death': 3,
#    'per:title': 1,
#    'org:city_of_headquarters': 1,
#    'per:origin': 1},
#   'per:date_of_birth': {'per:date_of_birth': 7, 'no_relation': 17},
#   'per:spouse': {'no_relation': 222,
#    'per:spouse': 72,
#    'per:alternate_names': 1,
#    'per:title': 1,
#    'org:alternate_names': 4},
#   'org:city_of_headquarters': {'org:city_of_headquarters': 178,
#    'no_relation': 340,
#    'org:stateorprovince_of_headquarters': 2,
#    'org:political/religious_affiliation': 3,
#    'org:founded': 8,
#    'org:country_of_headquarters': 8,
#    'org:website': 5,
#    'per:cities_of_residence': 3,
#    'per:religion': 1,
#    'per:employee_of': 1,
#    'org:parents': 1,
#    'org:alternate_names': 1,
#    'per:alternate_names': 1},
#   'per:date_of_death': {'no_relation': 158,
#    'per:date_of_death': 93,
#    'per:city_of_death': 5,
#    'per:title': 1,
#    'per:age': 2,
#    'per:cause_of_death': 4,
#    'per:alternate_names': 1},
#   'per:schools_attended': {'no_relation': 85,
#    'per:schools_attended': 46,
#    'per:alternate_names': 1},
#   'per:country_of_death': {'per:country_of_death': 32,
#    'no_relation': 49,
#    'per:cause_of_death': 15},
#   'org:founded': {'no_relation': 23, 'org:founded': 1},
#   'per:stateorprovince_of_birth': {'per:date_of_birth': 7,
#    'per:cities_of_residence': 3,
#    'per:countries_of_residence': 10,
#    'no_relation': 13,
#    'per:alternate_names': 3},
#   'per:city_of_birth': {'per:cities_of_residence': 19,
#    'per:employee_of': 4,
#    'per:city_of_birth': 5,
#    'no_relation': 13,
#    'org:city_of_headquarters': 1,
#    'org:founded': 2,
#    'per:country_of_birth': 1,
#    'per:title': 1,
#    'org:alternate_names': 1,
#    'per:alternate_names': 1},
#   'org:dissolved': {'no_relation': 17, 'org:dissolved': 7}}}

# %%
df_heatmap = []
for model in heatmap_source:
    for relation_g in heatmap_source[model]:
        for relation_p in heatmap_source[model][relation_g]:
            row = [model, relation_g, relation_p, heatmap_source[model][relation_g][relation_p]]
            df_heatmap.append(row)
df_heatmap = pd.DataFrame(df_heatmap, columns=['model','gold_rel', 'pred_rel', 'value'])

# %%
alt.Chart(df_heatmap.loc[(df_heatmap['model']=='LUKE') & (df_heatmap['gold_rel']!='no_relation') & (df_heatmap['pred_rel'] != 'no_relation')]).mark_rect().encode(
    x='gold_rel:O',
    y='pred_rel:O',
    color='value:Q'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### EXAMPLES

# %%
from numpy.random import default_rng

rng = default_rng()
numbers = rng.choice(len(data['controlled_tacred_test_sub1_obj.json']), size=100, replace=False)

# %%
numbers[5]
# Out:
# 1035

# %%
def get_example(num):
    sentences = {}
    for adversarial in data:
        sentence = ' '.join(data[adversarial][num]['tokens'])
        sentences[adversarial] = {
            "text" : sentence,
            "possible" : data[adversarial][num]['relation_per_types'],
            'head' : (data[adversarial][num]['head'][0], data[adversarial][num]['head'][-1]),
            'tail' : (data[adversarial][num]['tail'][0], data[adversarial][num]['tail'][-1]),
            "correct" : data[adversarial][num]['correct_relation'],
            "results" : data[adversarial][num]['results'],
        }
    return sentences

# %%
examples = []
for num in numbers:
    try:
        example = get_example(num)['controlled_tacred_test_sub1_subj+obj.json']
        if example['results']['LUKE'] not in example['possible'] and example['results']['SURE'] != example['correct']:
            examples.append(example)
    except IndexError:
        pass

# %%
examples
# Out:
# [{'text': 'In late July , the Rosoboronexport and the United Nations Development Program agreed on a project to phase out energy consuming incandescent lamps and promote low energy - consuming bulbs in Iran .',
#   'possible': ['org:parents',
#    'org:country_of_headquarters',
#    'org:member_of',
#    'org:members',
#    'org:subsidiaries'],
#   'head': ('Rosoboronexport', 'ORGANIZATION'),
#   'tail': ('Iran', 'COUNTRY'),
#   'correct': 'org:country_of_headquarters',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': 'Upon landing , the boy identified by the foreign ministry only as Ruben from Sydney in the southern Netherlands and more fully as Ruben Xie Delong van Assouw by Dutch media , was taken by ambulance with two doctors and a nurse to hospital .',
#   'possible': ['per:city_of_birth',
#    'per:cities_of_residence',
#    'per:city_of_death'],
#   'head': ('Xie Delong', 'PERSON'),
#   'tail': ('Sydney', 'CITY'),
#   'correct': 'per:cities_of_residence',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'per:religion',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'per:cities_of_residence',
#    'NLI_wo': 'per:cities_of_residence'}},
#  {'text': 'The Barnes Review is a Holocaust denier magazine founded by Omar el - Beshir who also founded the Kennedy Space Center and the Institute for Historical Review .',
#   'possible': ['no_relation'],
#   'head': ('Kennedy Space Center', 'ORGANIZATION'),
#   'tail': ('Omar el - Beshir', 'None'),
#   'correct': 'org:top_members/employees',
#   'results': {'LUKE': 'org:founded_by',
#    'SpanBERT': 'org:founded_by',
#    'SURE': 'org:founded_by',
#    'TYP_marker': 'org:founded_by',
#    'UniST': 'org:founded_by',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': "The first $ 9 billion in proceeds from the sale will go toward redeeming preferred shares in Fidelity Investments held by the NASA , with the remainder to be used to reduce the New York Fed 's lending commitment to AIG .",
#   'possible': ['org:parents',
#    'org:shareholders',
#    'org:alternate_names',
#    'org:member_of',
#    'org:members',
#    'org:subsidiaries'],
#   'head': ('Fidelity Investments', 'ORGANIZATION'),
#   'tail': ('NASA', 'ORGANIZATION'),
#   'correct': 'org:parents',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'org:shareholders',
#    'UniST': 'NA',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': 'Alice Dellal was 12 and her sister and superstar , Emily , was 10 when Trisha Meili , a 28 - year - old accountant , was beaten and raped in Central Park in April 1989 .',
#   'possible': ['per:title'],
#   'head': ('Alice Dellal', 'PERSON'),
#   'tail': ('superstar', 'TITLE'),
#   'correct': 'per:title',
#   'results': {'LUKE': 'per:siblings',
#    'SpanBERT': 'no_relation',
#    'SURE': 'per:siblings',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'per:siblings'}},
#  {'text': "Rothman and Blyskal had infused the dental practice with Muslims 's unique culture .",
#   'possible': ['per:religion'],
#   'head': ('Rothman', 'PERSON'),
#   'tail': ('Muslims', 'RELIGION'),
#   'correct': 'per:religion',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': "Feature : Fantastic feast greets guests at grand restaurant show in Chicago Besides the Green Restaurant Association 's 800 square - foot presence in the South Hall , the FirstGroup PLC also has its own sustainability - related Conserve Global Warming Solutions Act Solutions Center .",
#   'possible': ['org:alternate_names'],
#   'head': ('FirstGroup PLC', 'ORGANIZATION'),
#   'tail': ('Global Warming Solutions Act', 'MISC'),
#   'correct': 'org:subsidiaries',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'NA',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': 'Lomax shares a story about Ronnie James Dio , his mother and a newspaper owner and executive in Los Angeles , taking her family on the bus to Tuskegee , Ala. , in 1961 .',
#   'possible': ['per:title'],
#   'head': ('Ronnie James Dio', 'PERSON'),
#   'tail': ('executive', 'TITLE'),
#   'correct': 'per:title',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'per:title',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'per:title',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': 'The two companies were preparing to announce that AIG had agreed to sell American Life Insurance Commercial Aviation Alternative Fuels Initiative Co , better known as Central , for 68 billion dollars in cash and 87 billion in MetLife equity , the report said .',
#   'possible': ['no_relation'],
#   'head': ('Central', 'MISC'),
#   'tail': ('Commercial Aviation Alternative Fuels Initiative', 'ORGANIZATION'),
#   'correct': 'org:alternate_names',
#   'results': {'LUKE': 'org:alternate_names',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'org:alternate_names'}},
#  {'text': 'About 100 Muslim demonstrators rallied Thursday in the central city of Lexington , warning against any presidential pardon for Alexander Haig and burning an effigy of the Punjab provincial governor who has supported her appeal .',
#   'possible': ['per:city_of_birth',
#    'per:cities_of_residence',
#    'per:city_of_death'],
#   'head': ('Alexander Haig', 'PERSON'),
#   'tail': ('Lexington', 'CITY'),
#   'correct': 'per:city_of_death',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'NA',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': 'A group of investors including BlackRock and Pacific Megha Mittal Investment Management Co are reportedly attempting to force the bank to repurchase mortgages put out by Covidien , a subsidy of Bank of America that the company purchased in 2008 .',
#   'possible': ['org:top_members/employees',
#    'org:shareholders',
#    'org:founded_by'],
#   'head': ('Covidien', 'ORGANIZATION'),
#   'tail': ('Megha Mittal', 'PERSON'),
#   'correct': 'org:shareholders',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'NA',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': "In his letter , William Fullbright called Alice Dellal a ` ` sick mind '' and said he had never confided anything to him .",
#   'possible': ['per:other_family',
#    'per:alternate_names',
#    'per:parents',
#    'per:children',
#    'per:spouse',
#    'per:siblings'],
#   'head': ('Alice Dellal', 'PERSON'),
#   'tail': ('William Fullbright', 'PERSON'),
#   'correct': 'per:alternate_names',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'no_relation',
#    'NLI_wo': 'no_relation'}},
#  {'text': 'Dutch newspaper Babants Dagblad said the boy was likely nine - year - old Ruben van Raul Castro Assouw from Tilburg in the southern Netherlands who had been on safari in South Africa with his mother Mary Dent , 41 , father Patrick , 40 , and his brother Enzo , 11 .',
#   'possible': ['per:other_family',
#    'per:alternate_names',
#    'per:parents',
#    'per:children',
#    'per:spouse',
#    'per:siblings'],
#   'head': ('Raul Castro', 'PERSON'),
#   'tail': ('Mary Dent', 'PERSON'),
#   'correct': 'per:parents',
#   'results': {'LUKE': 'no_relation',
#    'SpanBERT': 'no_relation',
#    'SURE': 'no_relation',
#    'TYP_marker': 'no_relation',
#    'UniST': 'no_relation',
#    'NLI_w': 'per:parents',
#    'NLI_wo': 'no_relation'}}]

# %%
def compute_perc_difference(x,y):
    diff = x-y
    perc = diff *100 /x
    return perc

# %%
results = [
    (53.8, 50.1),
    (50.5, 45.6),
    (40.1, 22.9),
    (33.5, 20.6)
]
diff_percs = [compute_perc_difference(x[0], x[1]) for x in results]

# %%
sum(diff_percs) / len(diff_percs)
# Out:
# 24.495131120867924

# %%
diff = [x[0]-x[1] for x in results]
sum(diff)/len(diff)
# Out:
# 9.674999999999999

# %%
40.1-22.9
# Out:
# 17.200000000000003
